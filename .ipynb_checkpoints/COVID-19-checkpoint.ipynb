# %%
import json
import requests
from pprint import pprint
# from config import api_key
from pygments import highlight, lexers, formatters
import pandas as pd
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.cm import viridis
from matplotlib.colors import to_hex
import scipy.stats as st
import gmaps
import gmaps.datasets
import gmaps.geojson_geometries

# gmaps.configure(api_key = api_key)

# %%
## Data from https://rapidapi.com/

# make a call to the URL 
url = "https://corona-virus-world-and-india-data.p.rapidapi.com/api"

# pass key and host login
headers = {
    'x-rapidapi-host': "corona-virus-world-and-india-data.p.rapidapi.com",
    'x-rapidapi-key': "mNTV7WxSsqmshvTYBNiZHBqh6x8Wp1gRwifjsnRj6RKhp8LeTb"
    }

# Store the information from the GET call into the "response" variable

response = requests.request("GET", url, headers=headers)
pprint(response.json())
results = response.json()
# convert JSON into a python dictorinary format in order to read/loop through it.
# results = response.json()

# Print result to confirm
# pprint(results["countries_stat"])

# create for loop to get each result from countries stat which is the main key of the JSON
for key in results["countries_stat"]:
    print(key["country_name"])
# Out:
# {'countries_stat': [{'active_cases': '717,361',
#                      'cases': '849,092',
#                      'country_name': 'USA',
#                      'deaths': '47,681',
#                      'deaths_per_1m_population': '144',
#                      'new_cases': '375',
#                      'new_deaths': '22',
#                      'region': '',
#                      'serious_critical': '14,016',
#                      'tests_per_1m_population': '13,067',
#                      'total_cases_per_1m_population': '2,565',
#                      'total_recovered': '84,050',
#                      'total_tests': '4,325,342'},
#                     {'active_cases': '100,757',
#                      'cases': '208,389',
#                      'country_name': 'Spain',
#                      'deaths': '21,717',
#                      'deaths_per_1m_population': '464',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '7,705',
#                      'tests_per_1m_population': '19,896',
#                      'total_cases_per_1m_population': '4,457',
#                      'total_recovered': '85,915',
#                      'total_tests': '930,230'},
#                     {'active_cases': '107,699',
#                      'cases': '187,327',
#                      'country_name': 'Italy',
#                      'deaths': '25,085',
#                      'deaths_per_1m_population': '415',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '2,384',
#                      'tests_per_1m_population': '25,028',
#                      'total_cases_per_1m_population': '3,098',
#                      'total_recovered': '54,543',
#                      'total_tests': '1,513,251'},
#                     {'active_cases': '97,880',
#                      'cases': '159,877',
#                      'country_name': 'France',
#                      'deaths': '21,340',
#                      'deaths_per_1m_population': '327',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '5,218',
#                      'tests_per_1m_population': '7,103',
#                      'total_cases_per_1m_population': '2,449',
#                      'total_recovered': '40,657',
#                      'total_tests': '463,662'},
#                     {'active_cases': '42,033',
#                      'cases': '150,648',
#                      'country_name': 'Germany',
#                      'deaths': '5,315',
#                      'deaths_per_1m_population': '63',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '2,908',
#                      'tests_per_1m_population': '24,738',
#                      'total_cases_per_1m_population': '1,798',
#                      'total_recovered': '103,300',
#                      'total_tests': '2,072,669'},
#                     {'active_cases': '115,051',
#                      'cases': '133,495',
#                      'country_name': 'UK',
#                      'deaths': '18,100',
#                      'deaths_per_1m_population': '267',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '1,559',
#                      'tests_per_1m_population': '8,248',
#                      'total_cases_per_1m_population': '1,966',
#                      'total_recovered': 'N/A',
#                      'total_tests': '559,935'},
#                     {'active_cases': '79,821',
#                      'cases': '98,674',
#                      'country_name': 'Turkey',
#                      'deaths': '2,376',
#                      'deaths_per_1m_population': '28',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '1,814',
#                      'tests_per_1m_population': '8,904',
#                      'total_cases_per_1m_population': '1,170',
#                      'total_recovered': '16,477',
#                      'total_tests': '750,944'},
#                     {'active_cases': '17,492',
#                      'cases': '85,996',
#                      'country_name': 'Iran',
#                      'deaths': '5,391',
#                      'deaths_per_1m_population': '64',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '3,311',
#                      'tests_per_1m_population': '4,493',
#                      'total_cases_per_1m_population': '1,024',
#                      'total_recovered': '63,113',
#                      'total_tests': '377,396'},
#                     {'active_cases': '959',
#                      'cases': '82,798',
#                      'country_name': 'China',
#                      'deaths': '4,632',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '10',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '63',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '58',
#                      'total_recovered': '77,207',
#                      'total_tests': '0'},
#                     {'active_cases': '53,066',
#                      'cases': '57,999',
#                      'country_name': 'Russia',
#                      'deaths': '513',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '700',
#                      'tests_per_1m_population': '15,418',
#                      'total_cases_per_1m_population': '397',
#                      'total_recovered': '4,420',
#                      'total_tests': '2,250,000'},
#                     {'active_cases': '17,940',
#                      'cases': '46,182',
#                      'country_name': 'Brazil',
#                      'deaths': '2,924',
#                      'deaths_per_1m_population': '14',
#                      'new_cases': '425',
#                      'new_deaths': '18',
#                      'region': '',
#                      'serious_critical': '8,318',
#                      'tests_per_1m_population': '1,373',
#                      'total_cases_per_1m_population': '217',
#                      'total_recovered': '25,318',
#                      'total_tests': '291,922'},
#                     {'active_cases': '26,194',
#                      'cases': '41,889',
#                      'country_name': 'Belgium',
#                      'deaths': '6,262',
#                      'deaths_per_1m_population': '540',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '1,020',
#                      'tests_per_1m_population': '14,789',
#                      'total_cases_per_1m_population': '3,614',
#                      'total_recovered': '9,433',
#                      'total_tests': '171,400'},
#                     {'active_cases': '24,230',
#                      'cases': '40,190',
#                      'country_name': 'Canada',
#                      'deaths': '1,974',
#                      'deaths_per_1m_population': '52',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '557',
#                      'tests_per_1m_population': '16,220',
#                      'total_cases_per_1m_population': '1,065',
#                      'total_recovered': '13,986',
#                      'total_tests': '612,192'},
#                     {'active_cases': '30,538',
#                      'cases': '34,842',
#                      'country_name': 'Netherlands',
#                      'deaths': '4,054',
#                      'deaths_per_1m_population': '237',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '1,050',
#                      'tests_per_1m_population': '10,004',
#                      'total_cases_per_1m_population': '2,033',
#                      'total_recovered': 'N/A',
#                      'total_tests': '171,415'},
#                     {'active_cases': '6,859',
#                      'cases': '28,268',
#                      'country_name': 'Switzerland',
#                      'deaths': '1,509',
#                      'deaths_per_1m_population': '174',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '386',
#                      'tests_per_1m_population': '26,293',
#                      'total_cases_per_1m_population': '3,266',
#                      'total_recovered': '19,900',
#                      'total_tests': '227,554'},
#                     {'active_cases': '20,054',
#                      'cases': '21,982',
#                      'country_name': 'Portugal',
#                      'deaths': '785',
#                      'deaths_per_1m_population': '77',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '207',
#                      'tests_per_1m_population': '27,925',
#                      'total_cases_per_1m_population': '2,156',
#                      'total_recovered': '1,143',
#                      'total_tests': '284,741'},
#                     {'active_cases': '16,393',
#                      'cases': '21,450',
#                      'country_name': 'India',
#                      'deaths': '681',
#                      'deaths_per_1m_population': '0.5',
#                      'new_cases': '80',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '335',
#                      'total_cases_per_1m_population': '16',
#                      'total_recovered': '4,376',
#                      'total_tests': '462,621'},
#                     {'active_cases': '11,693',
#                      'cases': '19,250',
#                      'country_name': 'Peru',
#                      'deaths': '530',
#                      'deaths_per_1m_population': '16',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '396',
#                      'tests_per_1m_population': '5,168',
#                      'total_cases_per_1m_population': '584',
#                      'total_recovered': '7,027',
#                      'total_tests': '170,400'},
#                     {'active_cases': '6,669',
#                      'cases': '16,671',
#                      'country_name': 'Ireland',
#                      'deaths': '769',
#                      'deaths_per_1m_population': '156',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '147',
#                      'tests_per_1m_population': '22,598',
#                      'total_cases_per_1m_population': '3,376',
#                      'total_recovered': '9,233',
#                      'total_tests': '111,584'},
#                     {'active_cases': '13,517',
#                      'cases': '16,004',
#                      'country_name': 'Sweden',
#                      'deaths': '1,937',
#                      'deaths_per_1m_population': '192',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '515',
#                      'tests_per_1m_population': '9,357',
#                      'total_cases_per_1m_population': '1,585',
#                      'total_recovered': '550',
#                      'total_tests': '94,500'},
#                     {'active_cases': '3,087',
#                      'cases': '14,925',
#                      'country_name': 'Austria',
#                      'deaths': '510',
#                      'deaths_per_1m_population': '57',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '176',
#                      'tests_per_1m_population': '22,406',
#                      'total_cases_per_1m_population': '1,657',
#                      'total_recovered': '11,328',
#                      'total_tests': '201,794'},
#                     {'active_cases': '9,094',
#                      'cases': '14,498',
#                      'country_name': 'Israel',
#                      'deaths': '189',
#                      'deaths_per_1m_population': '22',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '141',
#                      'tests_per_1m_population': '27,763',
#                      'total_cases_per_1m_population': '1,675',
#                      'total_recovered': '5,215',
#                      'total_tests': '240,303'},
#                     {'active_cases': '10,846',
#                      'cases': '12,772',
#                      'country_name': 'Saudi Arabia',
#                      'deaths': '114',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '82',
#                      'tests_per_1m_population': '5,745',
#                      'total_cases_per_1m_population': '367',
#                      'total_recovered': '1,812',
#                      'total_tests': '200,000'},
#                     {'active_cases': '10,227',
#                      'cases': '11,950',
#                      'country_name': 'Japan',
#                      'deaths': '299',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '241',
#                      'tests_per_1m_population': '1,033',
#                      'total_cases_per_1m_population': '94',
#                      'total_recovered': '1,424',
#                      'total_tests': '130,587'},
#                     {'active_cases': '5,750',
#                      'cases': '11,296',
#                      'country_name': 'Chile',
#                      'deaths': '160',
#                      'deaths_per_1m_population': '8',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '399',
#                      'tests_per_1m_population': '6,734',
#                      'total_cases_per_1m_population': '591',
#                      'total_recovered': '5,386',
#                      'total_tests': '128,722'},
#                     {'active_cases': '9,051',
#                      'cases': '10,850',
#                      'country_name': 'Ecuador',
#                      'deaths': '537',
#                      'deaths_per_1m_population': '30',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '141',
#                      'tests_per_1m_population': '1,975',
#                      'total_cases_per_1m_population': '615',
#                      'total_recovered': '1,262',
#                      'total_tests': '34,840'},
#                     {'active_cases': '2,051',
#                      'cases': '10,702',
#                      'country_name': 'S. Korea',
#                      'deaths': '240',
#                      'deaths_per_1m_population': '5',
#                      'new_cases': '8',
#                      'new_deaths': '2',
#                      'region': '',
#                      'serious_critical': '55',
#                      'tests_per_1m_population': '11,390',
#                      'total_cases_per_1m_population': '209',
#                      'total_recovered': '8,411',
#                      'total_tests': '583,971'},
#                     {'active_cases': '6,947',
#                      'cases': '10,544',
#                      'country_name': 'Mexico',
#                      'deaths': '970',
#                      'deaths_per_1m_population': '8',
#                      'new_cases': '1,043',
#                      'new_deaths': '113',
#                      'region': '',
#                      'serious_critical': '378',
#                      'tests_per_1m_population': '384',
#                      'total_cases_per_1m_population': '82',
#                      'total_recovered': '2,627',
#                      'total_tests': '49,570'},
#                     {'active_cases': '7,952',
#                      'cases': '10,513',
#                      'country_name': 'Pakistan',
#                      'deaths': '224',
#                      'deaths_per_1m_population': '1',
#                      'new_cases': '437',
#                      'new_deaths': '12',
#                      'region': '',
#                      'serious_critical': '58',
#                      'tests_per_1m_population': '534',
#                      'total_cases_per_1m_population': '48',
#                      'total_recovered': '2,337',
#                      'total_tests': '118,020'},
#                     {'active_cases': '8,230',
#                      'cases': '10,169',
#                      'country_name': 'Poland',
#                      'deaths': '426',
#                      'deaths_per_1m_population': '11',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '160',
#                      'tests_per_1m_population': '6,310',
#                      'total_cases_per_1m_population': '269',
#                      'total_recovered': '1,513',
#                      'total_tests': '238,799'},
#                     {'active_cases': '9,233',
#                      'cases': '10,141',
#                      'country_name': 'Singapore',
#                      'deaths': '12',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '27',
#                      'tests_per_1m_population': '16,203',
#                      'total_cases_per_1m_population': '1,733',
#                      'total_recovered': '896',
#                      'total_tests': '94,796'},
#                     {'active_cases': '6,780',
#                      'cases': '9,710',
#                      'country_name': 'Romania',
#                      'deaths': '524',
#                      'deaths_per_1m_population': '27',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '288',
#                      'tests_per_1m_population': '5,529',
#                      'total_cases_per_1m_population': '505',
#                      'total_recovered': '2,406',
#                      'total_tests': '106,357'},
#                     {'active_cases': '6,640',
#                      'cases': '8,238',
#                      'country_name': 'UAE',
#                      'deaths': '52',
#                      'deaths_per_1m_population': '5',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '1',
#                      'tests_per_1m_population': '79,875',
#                      'total_cases_per_1m_population': '833',
#                      'total_recovered': '1,546',
#                      'total_tests': '790,000'},
#                     {'active_cases': '2,441',
#                      'cases': '7,912',
#                      'country_name': 'Denmark',
#                      'deaths': '384',
#                      'deaths_per_1m_population': '66',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '80',
#                      'tests_per_1m_population': '18,726',
#                      'total_cases_per_1m_population': '1,366',
#                      'total_recovered': '5,087',
#                      'total_tests': '108,465'},
#                     {'active_cases': '5,870',
#                      'cases': '7,418',
#                      'country_name': 'Indonesia',
#                      'deaths': '635',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '204',
#                      'total_cases_per_1m_population': '27',
#                      'total_recovered': '913',
#                      'total_tests': '55,732'},
#                     {'active_cases': '7,119',
#                      'cases': '7,338',
#                      'country_name': 'Norway',
#                      'deaths': '187',
#                      'deaths_per_1m_population': '34',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '54',
#                      'tests_per_1m_population': '27,421',
#                      'total_cases_per_1m_population': '1,354',
#                      'total_recovered': '32',
#                      'total_tests': '148,656'},
#                     {'active_cases': '6,454',
#                      'cases': '7,281',
#                      'country_name': 'Belarus',
#                      'deaths': '58',
#                      'deaths_per_1m_population': '6',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '92',
#                      'tests_per_1m_population': '12,165',
#                      'total_cases_per_1m_population': '771',
#                      'total_recovered': '769',
#                      'total_tests': '114,955'},
#                     {'active_cases': '6,442',
#                      'cases': '7,141',
#                      'country_name': 'Qatar',
#                      'deaths': '10',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '37',
#                      'tests_per_1m_population': '24,301',
#                      'total_cases_per_1m_population': '2,479',
#                      'total_recovered': '689',
#                      'total_tests': '70,012'},
#                     {'active_cases': '4,935',
#                      'cases': '7,132',
#                      'country_name': 'Czechia',
#                      'deaths': '208',
#                      'deaths_per_1m_population': '19',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '80',
#                      'tests_per_1m_population': '17,454',
#                      'total_cases_per_1m_population': '666',
#                      'total_recovered': '1,989',
#                      'total_tests': '186,918'},
#                     {'active_cases': '5,955',
#                      'cases': '7,114',
#                      'country_name': 'Serbia',
#                      'deaths': '134',
#                      'deaths_per_1m_population': '15',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '101',
#                      'tests_per_1m_population': '5,566',
#                      'total_cases_per_1m_population': '814',
#                      'total_recovered': '1,025',
#                      'total_tests': '48,636'},
#                     {'active_cases': '5,571',
#                      'cases': '6,710',
#                      'country_name': 'Philippines',
#                      'deaths': '446',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '1',
#                      'tests_per_1m_population': '625',
#                      'total_cases_per_1m_population': '61',
#                      'total_recovered': '693',
#                      'total_tests': '68,532'},
#                     {'active_cases': '1,544',
#                      'cases': '6,660',
#                      'country_name': 'Australia',
#                      'deaths': '75',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '11',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '46',
#                      'tests_per_1m_population': '18,185',
#                      'total_cases_per_1m_population': '261',
#                      'total_recovered': '5,041',
#                      'total_tests': '463,713'},
#                     {'active_cases': '5,994',
#                      'cases': '6,592',
#                      'country_name': 'Ukraine',
#                      'deaths': '174',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '45',
#                      'tests_per_1m_population': '1,544',
#                      'total_cases_per_1m_population': '151',
#                      'total_recovered': '424',
#                      'total_tests': '67,520'},
#                     {'active_cases': '1,987',
#                      'cases': '5,532',
#                      'country_name': 'Malaysia',
#                      'deaths': '93',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '43',
#                      'tests_per_1m_population': '3,515',
#                      'total_cases_per_1m_population': '171',
#                      'total_recovered': '3,452',
#                      'total_tests': '113,755'},
#                     {'active_cases': '4,459',
#                      'cases': '5,300',
#                      'country_name': 'Dominican Republic',
#                      'deaths': '260',
#                      'deaths_per_1m_population': '24',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '135',
#                      'tests_per_1m_population': '1,683',
#                      'total_cases_per_1m_population': '489',
#                      'total_recovered': '581',
#                      'total_tests': '18,261'},
#                     {'active_cases': '4,593',
#                      'cases': '4,992',
#                      'country_name': 'Panama',
#                      'deaths': '144',
#                      'deaths_per_1m_population': '33',
#                      'new_cases': '171',
#                      'new_deaths': '3',
#                      'region': '',
#                      'serious_critical': '97',
#                      'tests_per_1m_population': '5,261',
#                      'total_cases_per_1m_population': '1,157',
#                      'total_recovered': '255',
#                      'total_tests': '22,702'},
#                     {'active_cases': '3,280',
#                      'cases': '4,356',
#                      'country_name': 'Colombia',
#                      'deaths': '206',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '98',
#                      'tests_per_1m_population': '1,405',
#                      'total_cases_per_1m_population': '86',
#                      'total_recovered': '870',
#                      'total_tests': '71,500'},
#                     {'active_cases': '1,980',
#                      'cases': '4,129',
#                      'country_name': 'Finland',
#                      'deaths': '149',
#                      'deaths_per_1m_population': '27',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '63',
#                      'tests_per_1m_population': '12,372',
#                      'total_cases_per_1m_population': '745',
#                      'total_recovered': '2,000',
#                      'total_tests': '68,552'},
#                     {'active_cases': '3,560',
#                      'cases': '3,772',
#                      'country_name': 'Bangladesh',
#                      'deaths': '120',
#                      'deaths_per_1m_population': '0.7',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '1',
#                      'tests_per_1m_population': '198',
#                      'total_cases_per_1m_population': '23',
#                      'total_recovered': '92',
#                      'total_tests': '32,630'},
#                     {'active_cases': '2,448',
#                      'cases': '3,659',
#                      'country_name': 'Egypt',
#                      'deaths': '276',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '537',
#                      'total_cases_per_1m_population': '36',
#                      'total_recovered': '935',
#                      'total_tests': '55,000'},
#                     {'active_cases': '2,863',
#                      'cases': '3,654',
#                      'country_name': 'Luxembourg',
#                      'deaths': '80',
#                      'deaths_per_1m_population': '128',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '32',
#                      'tests_per_1m_population': '57,649',
#                      'total_cases_per_1m_population': '5,837',
#                      'total_recovered': '711',
#                      'total_tests': '36,087'},
#                     {'active_cases': '2,515',
#                      'cases': '3,635',
#                      'country_name': 'South Africa',
#                      'deaths': '65',
#                      'deaths_per_1m_population': '1',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '36',
#                      'tests_per_1m_population': '2,256',
#                      'total_cases_per_1m_population': '61',
#                      'total_recovered': '1,055',
#                      'total_tests': '133,774'},
#                     {'active_cases': '2,880',
#                      'cases': '3,446',
#                      'country_name': 'Morocco',
#                      'deaths': '149',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '1',
#                      'tests_per_1m_population': '539',
#                      'total_cases_per_1m_population': '93',
#                      'total_recovered': '417',
#                      'total_tests': '19,885'},
#                     {'active_cases': '2,257',
#                      'cases': '3,288',
#                      'country_name': 'Argentina',
#                      'deaths': '159',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '123',
#                      'tests_per_1m_population': '868',
#                      'total_cases_per_1m_population': '73',
#                      'total_recovered': '872',
#                      'total_tests': '39,228'},
#                     {'active_cases': '1,304',
#                      'cases': '2,910',
#                      'country_name': 'Algeria',
#                      'deaths': '402',
#                      'deaths_per_1m_population': '9',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '40',
#                      'tests_per_1m_population': '148',
#                      'total_cases_per_1m_population': '66',
#                      'total_recovered': '1,204',
#                      'total_tests': '6,500'},
#                     {'active_cases': '359',
#                      'cases': '2,839',
#                      'country_name': 'Thailand',
#                      'deaths': '50',
#                      'deaths_per_1m_population': '0.7',
#                      'new_cases': '13',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '61',
#                      'tests_per_1m_population': '2,043',
#                      'total_cases_per_1m_population': '41',
#                      'total_recovered': '2,430',
#                      'total_tests': '142,589'},
#                     {'active_cases': '2,143',
#                      'cases': '2,778',
#                      'country_name': 'Moldova',
#                      'deaths': '75',
#                      'deaths_per_1m_population': '19',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '212',
#                      'tests_per_1m_population': '2,916',
#                      'total_cases_per_1m_population': '689',
#                      'total_recovered': '560',
#                      'total_tests': '11,763'},
#                     {'active_cases': '1,710',
#                      'cases': '2,408',
#                      'country_name': 'Greece',
#                      'deaths': '121',
#                      'deaths_per_1m_population': '12',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '55',
#                      'tests_per_1m_population': '5,463',
#                      'total_cases_per_1m_population': '231',
#                      'total_recovered': '577',
#                      'total_tests': '56,944'},
#                     {'active_cases': '1,792',
#                      'cases': '2,248',
#                      'country_name': 'Kuwait',
#                      'deaths': '13',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '50',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '526',
#                      'total_recovered': '443',
#                      'total_tests': '0'},
#                     {'active_cases': '1,657',
#                      'cases': '2,191',
#                      'country_name': 'Kazakhstan',
#                      'deaths': '19',
#                      'deaths_per_1m_population': '1',
#                      'new_cases': '56',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '29',
#                      'tests_per_1m_population': '8,175',
#                      'total_cases_per_1m_population': '117',
#                      'total_recovered': '515',
#                      'total_tests': '153,492'},
#                     {'active_cases': '1,648',
#                      'cases': '2,168',
#                      'country_name': 'Hungary',
#                      'deaths': '225',
#                      'deaths_per_1m_population': '23',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '82',
#                      'tests_per_1m_population': '5,455',
#                      'total_cases_per_1m_population': '224',
#                      'total_recovered': '295',
#                      'total_tests': '52,702'},
#                     {'active_cases': '994',
#                      'cases': '2,027',
#                      'country_name': 'Bahrain',
#                      'deaths': '7',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '2',
#                      'tests_per_1m_population': '57,474',
#                      'total_cases_per_1m_population': '1,191',
#                      'total_recovered': '1,026',
#                      'total_tests': '97,796'},
#                     {'active_cases': '1,033',
#                      'cases': '1,950',
#                      'country_name': 'Croatia',
#                      'deaths': '48',
#                      'deaths_per_1m_population': '12',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '19',
#                      'tests_per_1m_population': '6,726',
#                      'total_cases_per_1m_population': '475',
#                      'total_recovered': '869',
#                      'total_tests': '27,614'},
#                     {'active_cases': '313',
#                      'cases': '1,785',
#                      'country_name': 'Iceland',
#                      'deaths': '10',
#                      'deaths_per_1m_population': '29',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '5',
#                      'tests_per_1m_population': '130,312',
#                      'total_cases_per_1m_population': '5,231',
#                      'total_recovered': '1,462',
#                      'total_tests': '44,468'},
#                     {'active_cases': '1,259',
#                      'cases': '1,716',
#                      'country_name': 'Uzbekistan',
#                      'deaths': '7',
#                      'deaths_per_1m_population': '0.2',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '8',
#                      'tests_per_1m_population': '4,482',
#                      'total_cases_per_1m_population': '51',
#                      'total_recovered': '450',
#                      'total_tests': '150,000'},
#                     {'active_cases': '402',
#                      'cases': '1,631',
#                      'country_name': 'Iraq',
#                      'deaths': '83',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '1,563',
#                      'total_cases_per_1m_population': '41',
#                      'total_recovered': '1,146',
#                      'total_tests': '62,880'},
#                     {'active_cases': '1,368',
#                      'cases': '1,614',
#                      'country_name': 'Oman',
#                      'deaths': '8',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '3',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '316',
#                      'total_recovered': '238',
#                      'total_tests': '0'},
#                     {'active_cases': '1,331',
#                      'cases': '1,559',
#                      'country_name': 'Estonia',
#                      'deaths': '44',
#                      'deaths_per_1m_population': '33',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '7',
#                      'tests_per_1m_population': '32,895',
#                      'total_cases_per_1m_population': '1,175',
#                      'total_recovered': '184',
#                      'total_tests': '43,637'},
#                     {'active_cases': '591',
#                      'cases': '1,518',
#                      'country_name': 'Azerbaijan',
#                      'deaths': '20',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '14',
#                      'tests_per_1m_population': '10,674',
#                      'total_cases_per_1m_population': '150',
#                      'total_recovered': '907',
#                      'total_tests': '108,221'},
#                     {'active_cases': '816',
#                      'cases': '1,473',
#                      'country_name': 'Armenia',
#                      'deaths': '24',
#                      'deaths_per_1m_population': '8',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '30',
#                      'tests_per_1m_population': '5,051',
#                      'total_cases_per_1m_population': '497',
#                      'total_recovered': '633',
#                      'total_tests': '14,966'},
#                     {'active_cases': '370',
#                      'cases': '1,451',
#                      'country_name': 'New Zealand',
#                      'deaths': '16',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '3',
#                      'new_deaths': '2',
#                      'region': '',
#                      'serious_critical': '2',
#                      'tests_per_1m_population': '21,002',
#                      'total_cases_per_1m_population': '301',
#                      'total_recovered': '1,065',
#                      'total_tests': '101,277'},
#                     {'active_cases': '975',
#                      'cases': '1,370',
#                      'country_name': 'Lithuania',
#                      'deaths': '38',
#                      'deaths_per_1m_population': '14',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '17',
#                      'tests_per_1m_population': '28,275',
#                      'total_cases_per_1m_population': '503',
#                      'total_recovered': '357',
#                      'total_tests': '76,973'},
#                     {'active_cases': '855',
#                      'cases': '1,368',
#                      'country_name': 'Bosnia and Herzegovina',
#                      'deaths': '53',
#                      'deaths_per_1m_population': '16',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '4',
#                      'tests_per_1m_population': '6,134',
#                      'total_cases_per_1m_population': '417',
#                      'total_recovered': '460',
#                      'total_tests': '20,125'},
#                     {'active_cases': '1,069',
#                      'cases': '1,353',
#                      'country_name': 'Slovenia',
#                      'deaths': '79',
#                      'deaths_per_1m_population': '38',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '24',
#                      'tests_per_1m_population': '21,374',
#                      'total_cases_per_1m_population': '651',
#                      'total_recovered': '205',
#                      'total_tests': '44,435'},
#                     {'active_cases': '931',
#                      'cases': '1,259',
#                      'country_name': 'North Macedonia',
#                      'deaths': '56',
#                      'deaths_per_1m_population': '27',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '8',
#                      'tests_per_1m_population': '6,240',
#                      'total_cases_per_1m_population': '604',
#                      'total_recovered': '272',
#                      'total_tests': '13,000'},
#                     {'active_cases': '946',
#                      'cases': '1,244',
#                      'country_name': 'Slovakia',
#                      'deaths': '14',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '7',
#                      'tests_per_1m_population': '9,643',
#                      'total_cases_per_1m_population': '228',
#                      'total_recovered': '284',
#                      'total_tests': '52,649'},
#                     {'active_cases': '808',
#                      'cases': '1,189',
#                      'country_name': 'Cuba',
#                      'deaths': '40',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '16',
#                      'tests_per_1m_population': '2,685',
#                      'total_cases_per_1m_population': '105',
#                      'total_recovered': '341',
#                      'total_tests': '30,416'},
#                     {'active_cases': '970',
#                      'cases': '1,176',
#                      'country_name': 'Afghanistan',
#                      'deaths': '40',
#                      'deaths_per_1m_population': '1',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '7',
#                      'tests_per_1m_population': '165',
#                      'total_cases_per_1m_population': '30',
#                      'total_recovered': '166',
#                      'total_tests': '6,422'},
#                     {'active_cases': '723',
#                      'cases': '1,163',
#                      'country_name': 'Cameroon',
#                      'deaths': '43',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '33',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '44',
#                      'total_recovered': '397',
#                      'total_tests': '0'},
#                     {'active_cases': '1,046',
#                      'cases': '1,154',
#                      'country_name': 'Ghana',
#                      'deaths': '9',
#                      'deaths_per_1m_population': '0.3',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '4',
# ...
#                     {'active_cases': '6',
#                      'cases': '11',
#                      'country_name': 'Burundi',
#                      'deaths': '1',
#                      'deaths_per_1m_population': '0.08',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '24',
#                      'total_cases_per_1m_population': '0.9',
#                      'total_recovered': '4',
#                      'total_tests': '284'},
#                     {'active_cases': '8',
#                      'cases': '11',
#                      'country_name': 'Falkland Islands',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '91,667',
#                      'total_cases_per_1m_population': '3,161',
#                      'total_recovered': '3',
#                      'total_tests': '319'},
#                     {'active_cases': '0',
#                      'cases': '11',
#                      'country_name': 'Greenland',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '20,257',
#                      'total_cases_per_1m_population': '194',
#                      'total_recovered': '11',
#                      'total_tests': '1,150'},
#                     {'active_cases': '9',
#                      'cases': '11',
#                      'country_name': 'Montserrat',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '1',
#                      'tests_per_1m_population': '7,212',
#                      'total_cases_per_1m_population': '2,204',
#                      'total_recovered': '2',
#                      'total_tests': '36'},
#                     {'active_cases': '6',
#                      'cases': '11',
#                      'country_name': 'Seychelles',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '112',
#                      'total_recovered': '5',
#                      'total_tests': '0'},
#                     {'active_cases': '6',
#                      'cases': '11',
#                      'country_name': 'Turks and Caicos',
#                      'deaths': '1',
#                      'deaths_per_1m_population': '26',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '2,144',
#                      'total_cases_per_1m_population': '284',
#                      'total_recovered': '4',
#                      'total_tests': '83'},
#                     {'active_cases': '1',
#                      'cases': '10',
#                      'country_name': 'Nicaragua',
#                      'deaths': '2',
#                      'deaths_per_1m_population': '0.3',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '2',
#                      'total_recovered': '7',
#                      'total_tests': '0'},
#                     {'active_cases': '7',
#                      'cases': '10',
#                      'country_name': 'Gambia',
#                      'deaths': '1',
#                      'deaths_per_1m_population': '0.4',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '131',
#                      'total_cases_per_1m_population': '4',
#                      'total_recovered': '2',
#                      'total_tests': '316'},
#                     {'active_cases': '3',
#                      'cases': '10',
#                      'country_name': 'Suriname',
#                      'deaths': '1',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '689',
#                      'total_cases_per_1m_population': '17',
#                      'total_recovered': '6',
#                      'total_tests': '404'},
#                     {'active_cases': '7',
#                      'cases': '9',
#                      'country_name': 'Vatican City',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '11,236',
#                      'total_recovered': '2',
#                      'total_tests': '0'},
#                     {'active_cases': '7',
#                      'cases': '9',
#                      'country_name': 'MS Zaandam',
#                      'deaths': '2',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '0',
#                      'total_recovered': '0',
#                      'total_tests': '0'},
#                     {'active_cases': '8',
#                      'cases': '8',
#                      'country_name': 'Papua New Guinea',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '68',
#                      'total_cases_per_1m_population': '0.9',
#                      'total_recovered': '0',
#                      'total_tests': '604'},
#                     {'active_cases': '4',
#                      'cases': '7',
#                      'country_name': 'Bhutan',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '11,603',
#                      'total_cases_per_1m_population': '9',
#                      'total_recovered': '3',
#                      'total_tests': '8,953'},
#                     {'active_cases': '0',
#                      'cases': '7',
#                      'country_name': 'Mauritania',
#                      'deaths': '1',
#                      'deaths_per_1m_population': '0.2',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '208',
#                      'total_cases_per_1m_population': '2',
#                      'total_recovered': '6',
#                      'total_tests': '969'},
#                     {'active_cases': '0',
#                      'cases': '6',
#                      'country_name': 'St. Barth',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '607',
#                      'total_recovered': '6',
#                      'total_tests': '0'},
#                     {'active_cases': '1',
#                      'cases': '6',
#                      'country_name': 'Western Sahara',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '10',
#                      'total_recovered': '5',
#                      'total_tests': '0'},
#                     {'active_cases': '1',
#                      'cases': '5',
#                      'country_name': 'British Virgin Islands',
#                      'deaths': '1',
#                      'deaths_per_1m_population': '33',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '165',
#                      'total_recovered': '3',
#                      'total_tests': '0'},
#                     {'active_cases': '5',
#                      'cases': '5',
#                      'country_name': 'Caribbean Netherlands',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '4,195',
#                      'total_cases_per_1m_population': '191',
#                      'total_recovered': '0',
#                      'total_tests': '110'},
#                     {'active_cases': '4',
#                      'cases': '4',
#                      'country_name': 'Sao Tome and Principe',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '87',
#                      'total_cases_per_1m_population': '18',
#                      'total_recovered': '0',
#                      'total_tests': '19'},
#                     {'active_cases': '4',
#                      'cases': '4',
#                      'country_name': 'South Sudan',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '0.4',
#                      'total_recovered': '0',
#                      'total_tests': '0'},
#                     {'active_cases': '2',
#                      'cases': '3',
#                      'country_name': 'Anguilla',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '200',
#                      'total_recovered': '1',
#                      'total_tests': '0'},
#                     {'active_cases': '1',
#                      'cases': '1',
#                      'country_name': 'Saint Pierre Miquelon',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '173',
#                      'total_recovered': '0',
#                      'total_tests': '0'},
#                     {'active_cases': '1',
#                      'cases': '1',
#                      'country_name': 'Yemen',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '0.03',
#                      'total_recovered': '0',
#                      'total_tests': '0'}],
#  'statistic_taken_at': '2020-04-23 04:58:01',
#  'world_total': {'active_cases': '1,732,232',
#                  'deaths_per_1m_population': '23.6',
#                  'new_cases': '2,761',
#                  'new_deaths': '182',
#                  'serious_critical': '56,676',
#                  'statistic_taken_at': '2020-04-23 04:58:01',
#                  'total_cases': '2,638,477',
#                  'total_cases_per_1m_population': '338',
#                  'total_deaths': '184,248',
#                  'total_recovered': '721,997'}}
# USA
# Spain
# Italy
# France
# Germany
# UK
# Turkey
# Iran
# China
# Russia
# Brazil
# Belgium
# Canada
# Netherlands
# Switzerland
# Portugal
# India
# Peru
# Ireland
# Sweden
# Austria
# Israel
# Saudi Arabia
# Japan
# Chile
# Ecuador
# S. Korea
# Mexico
# Pakistan
# Poland
# Singapore
# Romania
# UAE
# Denmark
# Indonesia
# Norway
# Belarus
# Qatar
# Czechia
# Serbia
# Philippines
# Australia
# Ukraine
# Malaysia
# Dominican Republic
# Panama
# Colombia
# Finland
# Bangladesh
# Egypt
# Luxembourg
# South Africa
# Morocco
# Argentina
# Algeria
# Thailand
# Moldova
# Greece
# Kuwait
# Kazakhstan
# Hungary
# Bahrain
# Croatia
# Iceland
# Uzbekistan
# Iraq
# Oman
# Estonia
# Azerbaijan
# Armenia
# New Zealand
# Lithuania
# Bosnia and Herzegovina
# Slovenia
# North Macedonia
# Slovakia
# Cuba
# Afghanistan
# Cameroon
# Ghana
# Hong Kong
# Bulgaria
# Djibouti
# Ivory Coast
# Tunisia
# Nigeria
# Cyprus
# Latvia
# Guinea
# Andorra
#
# Diamond Princess
# Lebanon
# Costa Rica
# Bolivia
# Niger
# Albania
# Kyrgyzstan
# Burkina Faso
# Uruguay
# Honduras
# Channel Islands
# San Marino
# Palestine
# Malta
# Senegal
# Jordan
# Taiwan
# Georgia
# Réunion
# DRC
# Guatemala
# Sri Lanka
# Mauritius
# Mayotte
# Montenegro
# Isle of Man
# Kenya
# Venezuela
# Mali
# Somalia
# Tanzania
# Vietnam
# Jamaica
# El Salvador
# Paraguay
# Congo
# Faeroe Islands
# Gabon
# Martinique
# Sudan
# Rwanda
# Guadeloupe
# Brunei
# Gibraltar
# Myanmar
# Cambodia
# Madagascar
# Ethiopia
# Trinidad and Tobago
# French Guiana
# Liberia
# Aruba
# Bermuda
# Monaco
# Togo
# Maldives
# Equatorial Guinea
# Liechtenstein
# Barbados
# Zambia
# Sint Maarten
# Cabo Verde
# Guyana
# Cayman Islands
# Bahamas
# Uganda
# Haiti
# Sierra Leone
# Libya
# French Polynesia
# Benin
# Guinea-Bissau
# Nepal
# Macao
# Syria
# Mozambique
# Eritrea
# Saint Martin
# Mongolia
# Chad
# Eswatini
# Zimbabwe
# Angola
# Antigua and Barbuda
# Malawi
# Timor-Leste
# Botswana
# Laos
# Belize
# Fiji
# New Caledonia
# Dominica
# Namibia
# Grenada
# Saint Lucia
# Saint Kitts and Nevis
# Curaçao
# CAR
# St. Vincent Grenadines
# Burundi
# Falkland Islands
# Greenland
# Montserrat
# Seychelles
# Turks and Caicos
# Nicaragua
# Gambia
# Suriname
# Vatican City
# MS Zaandam
# Papua New Guinea
# Bhutan
# Mauritania
# St. Barth
# Western Sahara
# British Virgin Islands
# Caribbean Netherlands
# Sao Tome and Principe
# South Sudan
# Anguilla
# Saint Pierre Miquelon
# Yemen

# %%
# print(results["countries_stat"])

# %%
# create a DataFrame from scratch (temporary to test)
pd.DataFrame(columns=["country_name"])

# create variable to hold the value belonging to each key in the dataset
countries = []
cases = []
deaths = []
active_cases = []
new_cases = []
new_deaths = []
total_recovered = []
serious_critical = []
deaths_per_1m_population = []
total_cases_per_1m_population = []

# total_tests = []

# for loop to store the data for each key
for key in results["countries_stat"]:
    countries.append(key["country_name"])
    cases.append(key["cases"])
    deaths.append(key["deaths"])
    new_deaths.append(key["new_deaths"])
    new_cases.append(key["new_cases"])
    active_cases.append(key["active_cases"])
    total_recovered.append(key["total_recovered"])
    serious_critical.append(key["serious_critical"])
    deaths_per_1m_population.append(key["deaths_per_1m_population"])
    total_cases_per_1m_population.append(key["total_cases_per_1m_population"])
    #total_tests.append(key["total_tests"])
    
# print(countries)

# %%
# Store dataframe into variable permanent

data = pd.DataFrame(columns=["Country", "Total Cases", "Total Deaths", "New Deaths", "New Cases", "Active Cases", "Total Recovered", "Serious Critical", "Deaths Per 1m_population", "Total Cases Per 1m_population"])
data["Country"] = countries
data["Total Cases"] = cases
data["Total Deaths"] = deaths
data["New Deaths"] = new_deaths
data["New Cases"] = new_cases
data["Active Cases"] = active_cases
data["Total Recovered"] = total_recovered
data["Serious Critical"] = serious_critical
data["Deaths Per 1m_population"] = deaths_per_1m_population
data["Total Cases Per 1m_population"] = total_cases_per_1m_population
# data['Total tests'] = total_tests
data.head(10)
# Out:
#    Country Total Cases Total Deaths New Deaths New Cases Active Cases  \
# 0      USA     849,092       47,681         22       375      717,361
# 1    Spain     208,389       21,717          0         0      100,757
# 2    Italy     187,327       25,085          0         0      107,699
# 3   France     159,877       21,340          0         0       97,880
# 4  Germany     150,648        5,315          0         0       42,033
# 5       UK     133,495       18,100          0         0      115,051
# 6   Turkey      98,674        2,376          0         0       79,821
# 7     Iran      85,996        5,391          0         0       17,492
# 8    China      82,798        4,632          0        10          959
# 9   Russia      57,999          513          0         0       53,066
#
#   Total Recovered Serious Critical Deaths Per 1m_population  \
# 0          84,050           14,016                      144
# 1          85,915            7,705                      464
# 2          54,543            2,384                      415
# 3          40,657            5,218                      327
# 4         103,300            2,908                       63
# 5             N/A            1,559                      267
# 6          16,477            1,814                       28
# 7          63,113            3,311                       64
# 8          77,207               63                        3
# 9           4,420              700                        4
#
#   Total Cases Per 1m_population
# 0                         2,565
# 1                         4,457
# 2                         3,098
# 3                         2,449
# 4                         1,798
# 5                         1,966
# 6                         1,170
# 7                         1,024
# 8                            58
# 9                           397

# %%
# use 06-Python-APIs/3/Activities/10-Stu_BankDeserts_Heatmap/Solved/Banking_Desert_HeatMap.ipynb
# for heatmap and plot chart

# %%
gmaps.configure(api_key='AIzaSyD018AY9UMzY50LnSAb4n8imcYiVPoyGoQ')

marker_locations = [
    (46.227638, 2.213749),
    (51.165691, 10.451526),
    (41.87194, 12.56738),
    (40.463667, -3.74922),
    (37.09024, -95.712891),
    (55.378051, -3.435973),
    (38.963745, 35.243322),
    (32.427908, 53.688046),
    (35.86166, 104.195397),
    (61.52401, 105.318756)
]

fig = gmaps.figure()
markers = gmaps.marker_layer(marker_locations)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
data["Total Deaths"] = data["Total Deaths"].str.replace("N/A","0")
data["Total Deaths"] = data["Total Deaths"].str.replace(",","").astype(float)
data.sort_values(['Total Deaths'], axis=0, ascending=False, inplace=True)
deaths_df = data[["Country","Total Deaths"]]
deaths_df.reset_index(inplace=True)

deaths_df.iloc[0:20]
# Out:
#     index      Country  Total Deaths
# 0       0          USA       47681.0
# 1       2        Italy       25085.0
# 2       1        Spain       21717.0
# 3       3       France       21340.0
# 4       5           UK       18100.0
# 5      11      Belgium        6262.0
# 6       7         Iran        5391.0
# 7       4      Germany        5315.0
# 8       8        China        4632.0
# 9      13  Netherlands        4054.0
# 10     10       Brazil        2924.0
# 11      6       Turkey        2376.0
# 12     12       Canada        1974.0
# 13     19       Sweden        1937.0
# 14     14  Switzerland        1509.0
# 15     27       Mexico         970.0
# 16     15     Portugal         785.0
# 17     18      Ireland         769.0
# 18     16        India         681.0
# 19     34    Indonesia         635.0

# %%
#Death comparision between countries
toptwenty = deaths_df.iloc[0:20]
toptwenty.plot(kind="bar", figsize=(8,5))
x_axis = np.arange(len(toptwenty))
tick_locations = [value for value in x_axis]
# Set a title for the chart
plt.title("Average Deaths per Country (Top 20)")
plt.xticks(tick_locations, data["Country"], rotation="vertical")
plt.ylabel("Number of Cases")
plt.xlabel("Countries")
plt.show()
plt.tight_layout()
plt.savefig('deathsCompare')
# Out:
# <img src="data:image/png;base64,..." width="799.259315720969">

# %%
data["Total Cases"] = data["Total Cases"].str.replace("N/A","0")
data["Total Cases"] = data["Total Cases"].str.replace(",","").astype(float)
data["Active Cases"] = data["Active Cases"].str.replace("N/A","0")
data["Active Cases"] = data["Active Cases"].str.replace(",","").astype(float)
data.dtypes
# Out:
# Country                           object
# Total Cases                      float64
# Total Deaths                      object
# New Deaths                        object
# New Cases                         object
# Active Cases                     float64
# Total Recovered                   object
# Serious Critical                  object
# Deaths Per 1m_population          object
# Total Cases Per 1m_population     object
# dtype: object

# %%
total_cases = data[["Country", "Total Cases","Active Cases"]]

world_avg = total_cases.mean()
print(world_avg)
# Out:
# Total Cases     12390.600939
# Active Cases     8132.830986
# dtype: float64

# %%
total_cases.head()
frame_df = pd.DataFrame({
    "Countries": ["World Avg", "USA"],
    "Total Cases": [12357.065728, 845822.0],
    "Active Cases": [8125.807512, 714426.0]
})
frame_df.set_index("Countries",drop=True,inplace=True)
frame_df
frame_df.plot(kind="bar", figsize=(8,4))
plt.title("World Average vs USA")
plt.ylabel("Number of Cases")
plt.xlabel("Countries")
plt.show()
plt.tight_layout()
plt.savefig('WorldAvgvsUS')
# Out:
# <img src="data:image/png;base64,..." width="799.259315720969">
