# %%
import json
import requests
import os 
from pprint import pprint

# from config import api_key

import pandas as pd
import numpy as np
import folium
import gmaps
import gmaps.datasets
import gmaps.geojson_geometries
import matplotlib.pyplot as plt
import scipy.stats as sts

from matplotlib.cm import viridis
from matplotlib.colors import to_hex
from pygments import highlight, lexers, formatters
from flask import jsonify
from matplotlib import pyplot as plt

API_PUBLIC = os.environ.get("PUBLIC_KEY")
API_SECRET = os.environ.get("SECRET_KEY")

# %%
## Data from https://rapidapi.com/

# make a call to the URL 
url = "https://corona-virus-world-and-india-data.p.rapidapi.com/api"

# pass key and host login
headers = {
    'x-rapidapi-host': "corona-virus-world-and-india-data.p.rapidapi.com",
    'x-rapidapi-key': "mNTV7WxSsqmshvTYBNiZHBqh6x8Wp1gRwifjsnRj6RKhp8LeTb"
    }

# Store the information from the GET call into the "response" variable
response = requests.request("GET", url, headers=headers)
pprint(response.json())

# create for loop to get each result from countries stat which is the main key of the JSON
for key in results["countries_stat"]:
    print(key["country_name"])
# Out:
# {'countries_stat': [{'active_cases': '743,596',
#                      'cases': '878,974',
#                      'country_name': 'USA',
#                      'deaths': '49,754',
#                      'deaths_per_1m_population': '150',
#                      'new_cases': '30,257',
#                      'new_deaths': '2,095',
#                      'region': '',
#                      'serious_critical': '14,997',
#                      'tests_per_1m_population': '14,173',
#                      'total_cases_per_1m_population': '2,655',
#                      'total_recovered': '85,624',
#                      'total_tests': '4,691,281'},
#                     {'active_cases': '101,617',
#                      'cases': '213,024',
#                      'country_name': 'Spain',
#                      'deaths': '22,157',
#                      'deaths_per_1m_population': '474',
#                      'new_cases': '4,635',
#                      'new_deaths': '440',
#                      'region': '',
#                      'serious_critical': '7,705',
#                      'tests_per_1m_population': '19,896',
#                      'total_cases_per_1m_population': '4,556',
#                      'total_recovered': '89,250',
#                      'total_tests': '930,230'},
#                     {'active_cases': '106,848',
#                      'cases': '189,973',
#                      'country_name': 'Italy',
#                      'deaths': '25,549',
#                      'deaths_per_1m_population': '423',
#                      'new_cases': '2,646',
#                      'new_deaths': '464',
#                      'region': '',
#                      'serious_critical': '2,267',
#                      'tests_per_1m_population': '26,131',
#                      'total_cases_per_1m_population': '3,142',
#                      'total_recovered': '57,576',
#                      'total_tests': '1,579,909'},
#                     {'active_cases': '94,239',
#                      'cases': '158,183',
#                      'country_name': 'France',
#                      'deaths': '21,856',
#                      'deaths_per_1m_population': '335',
#                      'new_cases': '2,239',
#                      'new_deaths': '516',
#                      'region': '',
#                      'serious_critical': '5,053',
#                      'tests_per_1m_population': '7,103',
#                      'total_cases_per_1m_population': '2,423',
#                      'total_recovered': '42,088',
#                      'total_tests': '463,662'},
#                     {'active_cases': '44,254',
#                      'cases': '153,129',
#                      'country_name': 'Germany',
#                      'deaths': '5,575',
#                      'deaths_per_1m_population': '67',
#                      'new_cases': '2,481',
#                      'new_deaths': '260',
#                      'region': '',
#                      'serious_critical': '2,908',
#                      'tests_per_1m_population': '24,738',
#                      'total_cases_per_1m_population': '1,828',
#                      'total_recovered': '103,300',
#                      'total_tests': '2,072,669'},
#                     {'active_cases': '118,996',
#                      'cases': '138,078',
#                      'country_name': 'UK',
#                      'deaths': '18,738',
#                      'deaths_per_1m_population': '276',
#                      'new_cases': '4,583',
#                      'new_deaths': '638',
#                      'region': '',
#                      'serious_critical': '1,559',
#                      'tests_per_1m_population': '8,595',
#                      'total_cases_per_1m_population': '2,034',
#                      'total_recovered': 'N/A',
#                      'total_tests': '583,496'},
#                     {'active_cases': '80,808',
#                      'cases': '101,790',
#                      'country_name': 'Turkey',
#                      'deaths': '2,491',
#                      'deaths_per_1m_population': '30',
#                      'new_cases': '3,116',
#                      'new_deaths': '115',
#                      'region': '',
#                      'serious_critical': '1,816',
#                      'tests_per_1m_population': '9,390',
#                      'total_cases_per_1m_population': '1,207',
#                      'total_recovered': '18,491',
#                      'total_tests': '791,906'},
#                     {'active_cases': '16,702',
#                      'cases': '87,026',
#                      'country_name': 'Iran',
#                      'deaths': '5,481',
#                      'deaths_per_1m_population': '65',
#                      'new_cases': '1,030',
#                      'new_deaths': '90',
#                      'region': '',
#                      'serious_critical': '3,105',
#                      'tests_per_1m_population': '4,637',
#                      'total_cases_per_1m_population': '1,036',
#                      'total_recovered': '64,843',
#                      'total_tests': '389,507'},
#                     {'active_cases': '959',
#                      'cases': '82,798',
#                      'country_name': 'China',
#                      'deaths': '4,632',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '10',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '63',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '58',
#                      'total_recovered': '77,207',
#                      'total_tests': '0'},
#                     {'active_cases': '57,327',
#                      'cases': '62,773',
#                      'country_name': 'Russia',
#                      'deaths': '555',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '4,774',
#                      'new_deaths': '42',
#                      'region': '',
#                      'serious_critical': '2,300',
#                      'tests_per_1m_population': '16,457',
#                      'total_cases_per_1m_population': '430',
#                      'total_recovered': '4,891',
#                      'total_tests': '2,401,616'},
#                     {'active_cases': '19,606',
#                      'cases': '49,492',
#                      'country_name': 'Brazil',
#                      'deaths': '3,313',
#                      'deaths_per_1m_population': '16',
#                      'new_cases': '3,735',
#                      'new_deaths': '407',
#                      'region': '',
#                      'serious_critical': '8,318',
#                      'tests_per_1m_population': '1,373',
#                      'total_cases_per_1m_population': '233',
#                      'total_recovered': '26,573',
#                      'total_tests': '291,922'},
#                     {'active_cases': '26,507',
#                      'cases': '42,797',
#                      'country_name': 'Belgium',
#                      'deaths': '6,490',
#                      'deaths_per_1m_population': '560',
#                      'new_cases': '908',
#                      'new_deaths': '228',
#                      'region': '',
#                      'serious_critical': '993',
#                      'tests_per_1m_population': '15,502',
#                      'total_cases_per_1m_population': '3,693',
#                      'total_recovered': '9,800',
#                      'total_tests': '179,666'},
#                     {'active_cases': '25,202',
#                      'cases': '42,110',
#                      'country_name': 'Canada',
#                      'deaths': '2,147',
#                      'deaths_per_1m_population': '57',
#                      'new_cases': '1,920',
#                      'new_deaths': '173',
#                      'region': '',
#                      'serious_critical': '557',
#                      'tests_per_1m_population': '16,430',
#                      'total_cases_per_1m_population': '1,116',
#                      'total_recovered': '14,761',
#                      'total_tests': '620,101'},
#                     {'active_cases': '31,302',
#                      'cases': '35,729',
#                      'country_name': 'Netherlands',
#                      'deaths': '4,177',
#                      'deaths_per_1m_population': '244',
#                      'new_cases': '887',
#                      'new_deaths': '123',
#                      'region': '',
#                      'serious_critical': '1,008',
#                      'tests_per_1m_population': '10,913',
#                      'total_cases_per_1m_population': '2,085',
#                      'total_recovered': 'N/A',
#                      'total_tests': '187,000'},
#                     {'active_cases': '6,347',
#                      'cases': '28,496',
#                      'country_name': 'Switzerland',
#                      'deaths': '1,549',
#                      'deaths_per_1m_population': '179',
#                      'new_cases': '228',
#                      'new_deaths': '40',
#                      'region': '',
#                      'serious_critical': '386',
#                      'tests_per_1m_population': '26,293',
#                      'total_cases_per_1m_population': '3,293',
#                      'total_recovered': '20,600',
#                      'total_tests': '227,554'},
#                     {'active_cases': '17,306',
#                      'cases': '23,039',
#                      'country_name': 'India',
#                      'deaths': '721',
#                      'deaths_per_1m_population': '0.5',
#                      'new_cases': '1,669',
#                      'new_deaths': '40',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '363',
#                      'total_cases_per_1m_population': '17',
#                      'total_recovered': '5,012',
#                      'total_tests': '500,542'},
#                     {'active_cases': '20,332',
#                      'cases': '22,353',
#                      'country_name': 'Portugal',
#                      'deaths': '820',
#                      'deaths_per_1m_population': '80',
#                      'new_cases': '371',
#                      'new_deaths': '35',
#                      'region': '',
#                      'serious_critical': '204',
#                      'tests_per_1m_population': '29,473',
#                      'total_cases_per_1m_population': '2,192',
#                      'total_recovered': '1,201',
#                      'total_tests': '300,525'},
#                     {'active_cases': '12,920',
#                      'cases': '20,914',
#                      'country_name': 'Peru',
#                      'deaths': '572',
#                      'deaths_per_1m_population': '17',
#                      'new_cases': '1,664',
#                      'new_deaths': '42',
#                      'region': '',
#                      'serious_critical': '396',
#                      'tests_per_1m_population': '5,618',
#                      'total_cases_per_1m_population': '634',
#                      'total_recovered': '7,422',
#                      'total_tests': '185,238'},
#                     {'active_cases': '7,580',
#                      'cases': '17,607',
#                      'country_name': 'Ireland',
#                      'deaths': '794',
#                      'deaths_per_1m_population': '161',
#                      'new_cases': '936',
#                      'new_deaths': '25',
#                      'region': '',
#                      'serious_critical': '147',
#                      'tests_per_1m_population': '22,598',
#                      'total_cases_per_1m_population': '3,566',
#                      'total_recovered': '9,233',
#                      'total_tests': '111,584'},
#                     {'active_cases': '14,184',
#                      'cases': '16,755',
#                      'country_name': 'Sweden',
#                      'deaths': '2,021',
#                      'deaths_per_1m_population': '200',
#                      'new_cases': '751',
#                      'new_deaths': '84',
#                      'region': '',
#                      'serious_critical': '533',
#                      'tests_per_1m_population': '9,357',
#                      'total_cases_per_1m_population': '1,659',
#                      'total_recovered': '550',
#                      'total_tests': '94,500'},
#                     {'active_cases': '2,786',
#                      'cases': '15,002',
#                      'country_name': 'Austria',
#                      'deaths': '522',
#                      'deaths_per_1m_population': '58',
#                      'new_cases': '77',
#                      'new_deaths': '12',
#                      'region': '',
#                      'serious_critical': '169',
#                      'tests_per_1m_population': '22,854',
#                      'total_cases_per_1m_population': '1,666',
#                      'total_recovered': '11,694',
#                      'total_tests': '205,835'},
#                     {'active_cases': '9,000',
#                      'cases': '14,803',
#                      'country_name': 'Israel',
#                      'deaths': '192',
#                      'deaths_per_1m_population': '22',
#                      'new_cases': '305',
#                      'new_deaths': '3',
#                      'region': '',
#                      'serious_critical': '139',
#                      'tests_per_1m_population': '27,763',
#                      'total_cases_per_1m_population': '1,710',
#                      'total_recovered': '5,611',
#                      'total_tests': '240,303'},
#                     {'active_cases': '11,884',
#                      'cases': '13,930',
#                      'country_name': 'Saudi Arabia',
#                      'deaths': '121',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '1,158',
#                      'new_deaths': '7',
#                      'region': '',
#                      'serious_critical': '93',
#                      'tests_per_1m_population': '5,745',
#                      'total_cases_per_1m_population': '400',
#                      'total_recovered': '1,925',
#                      'total_tests': '200,000'},
#                     {'active_cases': '10,227',
#                      'cases': '11,950',
#                      'country_name': 'Japan',
#                      'deaths': '299',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '241',
#                      'tests_per_1m_population': '1,033',
#                      'total_cases_per_1m_population': '94',
#                      'total_recovered': '1,424',
#                      'total_tests': '130,587'},
#                     {'active_cases': '5,840',
#                      'cases': '11,812',
#                      'country_name': 'Chile',
#                      'deaths': '168',
#                      'deaths_per_1m_population': '9',
#                      'new_cases': '516',
#                      'new_deaths': '8',
#                      'region': '',
#                      'serious_critical': '411',
#                      'tests_per_1m_population': '7,070',
#                      'total_cases_per_1m_population': '618',
#                      'total_recovered': '5,804',
#                      'total_tests': '135,147'},
#                     {'active_cases': '9,295',
#                      'cases': '11,183',
#                      'country_name': 'Ecuador',
#                      'deaths': '560',
#                      'deaths_per_1m_population': '32',
#                      'new_cases': '333',
#                      'new_deaths': '23',
#                      'region': '',
#                      'serious_critical': '141',
#                      'tests_per_1m_population': '1,975',
#                      'total_cases_per_1m_population': '634',
#                      'total_recovered': '1,328',
#                      'total_tests': '34,840'},
#                     {'active_cases': '10,242',
#                      'cases': '11,178',
#                      'country_name': 'Singapore',
#                      'deaths': '12',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '1,037',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '26',
#                      'tests_per_1m_population': '16,203',
#                      'total_cases_per_1m_population': '1,911',
#                      'total_recovered': '924',
#                      'total_tests': '94,796'},
#                     {'active_cases': '8,485',
#                      'cases': '11,057',
#                      'country_name': 'Pakistan',
#                      'deaths': '235',
#                      'deaths_per_1m_population': '1',
#                      'new_cases': '981',
#                      'new_deaths': '23',
#                      'region': '',
#                      'serious_critical': '60',
#                      'tests_per_1m_population': '564',
#                      'total_cases_per_1m_population': '50',
#                      'total_recovered': '2,337',
#                      'total_tests': '124,549'},
#                     {'active_cases': '2,051',
#                      'cases': '10,702',
#                      'country_name': 'S. Korea',
#                      'deaths': '240',
#                      'deaths_per_1m_population': '5',
#                      'new_cases': '8',
#                      'new_deaths': '2',
#                      'region': '',
#                      'serious_critical': '55',
#                      'tests_per_1m_population': '11,390',
#                      'total_cases_per_1m_population': '209',
#                      'total_recovered': '8,411',
#                      'total_tests': '583,971'},
#                     {'active_cases': '6,947',
#                      'cases': '10,544',
#                      'country_name': 'Mexico',
#                      'deaths': '970',
#                      'deaths_per_1m_population': '8',
#                      'new_cases': '1,043',
#                      'new_deaths': '113',
#                      'region': '',
#                      'serious_critical': '378',
#                      'tests_per_1m_population': '384',
#                      'total_cases_per_1m_population': '82',
#                      'total_recovered': '2,627',
#                      'total_tests': '49,570'},
#                     {'active_cases': '8,317',
#                      'cases': '10,511',
#                      'country_name': 'Poland',
#                      'deaths': '454',
#                      'deaths_per_1m_population': '12',
#                      'new_cases': '342',
#                      'new_deaths': '28',
#                      'region': '',
#                      'serious_critical': '160',
#                      'tests_per_1m_population': '6,625',
#                      'total_cases_per_1m_population': '278',
#                      'total_recovered': '1,740',
#                      'total_tests': '250,719'},
#                     {'active_cases': '7,073',
#                      'cases': '10,096',
#                      'country_name': 'Romania',
#                      'deaths': '545',
#                      'deaths_per_1m_population': '28',
#                      'new_cases': '386',
#                      'new_deaths': '21',
#                      'region': '',
#                      'serious_critical': '236',
#                      'tests_per_1m_population': '5,891',
#                      'total_cases_per_1m_population': '525',
#                      'total_recovered': '2,478',
#                      'total_tests': '113,336'},
#                     {'active_cases': '7,063',
#                      'cases': '8,756',
#                      'country_name': 'UAE',
#                      'deaths': '56',
#                      'deaths_per_1m_population': '6',
#                      'new_cases': '518',
#                      'new_deaths': '4',
#                      'region': '',
#                      'serious_critical': '1',
#                      'tests_per_1m_population': '79,875',
#                      'total_cases_per_1m_population': '885',
#                      'total_recovered': '1,637',
#                      'total_tests': '790,000'},
#                     {'active_cases': '2,295',
#                      'cases': '8,073',
#                      'country_name': 'Denmark',
#                      'deaths': '394',
#                      'deaths_per_1m_population': '68',
#                      'new_cases': '161',
#                      'new_deaths': '10',
#                      'region': '',
#                      'serious_critical': '74',
#                      'tests_per_1m_population': '20,134',
#                      'total_cases_per_1m_population': '1,394',
#                      'total_recovered': '5,384',
#                      'total_tests': '116,621'},
#                     {'active_cases': '7,024',
#                      'cases': '8,022',
#                      'country_name': 'Belarus',
#                      'deaths': '60',
#                      'deaths_per_1m_population': '6',
#                      'new_cases': '741',
#                      'new_deaths': '2',
#                      'region': '',
#                      'serious_critical': '92',
#                      'tests_per_1m_population': '12,968',
#                      'total_cases_per_1m_population': '849',
#                      'total_recovered': '938',
#                      'total_tests': '122,543'},
#                     {'active_cases': '6,168',
#                      'cases': '7,775',
#                      'country_name': 'Indonesia',
#                      'deaths': '647',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '357',
#                      'new_deaths': '12',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '219',
#                      'total_cases_per_1m_population': '28',
#                      'total_recovered': '960',
#                      'total_tests': '59,935'},
#                     {'active_cases': '7,004',
#                      'cases': '7,764',
#                      'country_name': 'Qatar',
#                      'deaths': '10',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '623',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '72',
#                      'tests_per_1m_population': '25,497',
#                      'total_cases_per_1m_population': '2,695',
#                      'total_recovered': '750',
#                      'total_tests': '73,457'},
#                     {'active_cases': '7,175',
#                      'cases': '7,401',
#                      'country_name': 'Norway',
#                      'deaths': '194',
#                      'deaths_per_1m_population': '36',
#                      'new_cases': '63',
#                      'new_deaths': '7',
#                      'region': '',
#                      'serious_critical': '50',
#                      'tests_per_1m_population': '28,055',
#                      'total_cases_per_1m_population': '1,365',
#                      'total_recovered': '32',
#                      'total_tests': '152,095'},
#                     {'active_cases': '6,074',
#                      'cases': '7,276',
#                      'country_name': 'Serbia',
#                      'deaths': '139',
#                      'deaths_per_1m_population': '16',
#                      'new_cases': '162',
#                      'new_deaths': '5',
#                      'region': '',
#                      'serious_critical': '96',
#                      'tests_per_1m_population': '5,874',
#                      'total_cases_per_1m_population': '833',
#                      'total_recovered': '1,063',
#                      'total_tests': '51,324'},
#                     {'active_cases': '4,825',
#                      'cases': '7,187',
#                      'country_name': 'Czechia',
#                      'deaths': '210',
#                      'deaths_per_1m_population': '20',
#                      'new_cases': '55',
#                      'new_deaths': '2',
#                      'region': '',
#                      'serious_critical': '76',
#                      'tests_per_1m_population': '18,277',
#                      'total_cases_per_1m_population': '671',
#                      'total_recovered': '2,152',
#                      'total_tests': '195,725'},
#                     {'active_cases': '6,479',
#                      'cases': '7,170',
#                      'country_name': 'Ukraine',
#                      'deaths': '187',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '578',
#                      'new_deaths': '13',
#                      'region': '',
#                      'serious_critical': '45',
#                      'tests_per_1m_population': '1,653',
#                      'total_cases_per_1m_population': '164',
#                      'total_recovered': '504',
#                      'total_tests': '72,296'},
#                     {'active_cases': '5,797',
#                      'cases': '6,981',
#                      'country_name': 'Philippines',
#                      'deaths': '462',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '271',
#                      'new_deaths': '16',
#                      'region': '',
#                      'serious_critical': '1',
#                      'tests_per_1m_population': '660',
#                      'total_cases_per_1m_population': '64',
#                      'total_recovered': '722',
#                      'total_tests': '72,346'},
#                     {'active_cases': '1,547',
#                      'cases': '6,667',
#                      'country_name': 'Australia',
#                      'deaths': '75',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '18',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '45',
#                      'tests_per_1m_population': '18,300',
#                      'total_cases_per_1m_population': '261',
#                      'total_recovered': '5,045',
#                      'total_tests': '466,659'},
#                     {'active_cases': '1,966',
#                      'cases': '5,603',
#                      'country_name': 'Malaysia',
#                      'deaths': '95',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '71',
#                      'new_deaths': '2',
#                      'region': '',
#                      'serious_critical': '42',
#                      'tests_per_1m_population': '3,627',
#                      'total_cases_per_1m_population': '173',
#                      'total_recovered': '3,542',
#                      'total_tests': '117,406'},
#                     {'active_cases': '4,697',
#                      'cases': '5,543',
#                      'country_name': 'Dominican Republic',
#                      'deaths': '265',
#                      'deaths_per_1m_population': '24',
#                      'new_cases': '243',
#                      'new_deaths': '5',
#                      'region': '',
#                      'serious_critical': '135',
#                      'tests_per_1m_population': '1,683',
#                      'total_cases_per_1m_population': '511',
#                      'total_recovered': '581',
#                      'total_tests': '18,261'},
#                     {'active_cases': '4,593',
#                      'cases': '4,992',
#                      'country_name': 'Panama',
#                      'deaths': '144',
#                      'deaths_per_1m_population': '33',
#                      'new_cases': '171',
#                      'new_deaths': '3',
#                      'region': '',
#                      'serious_critical': '97',
#                      'tests_per_1m_population': '5,261',
#                      'total_cases_per_1m_population': '1,157',
#                      'total_recovered': '255',
#                      'total_tests': '22,702'},
#                     {'active_cases': '3,419',
#                      'cases': '4,561',
#                      'country_name': 'Colombia',
#                      'deaths': '215',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '205',
#                      'new_deaths': '9',
#                      'region': '',
#                      'serious_critical': '98',
#                      'tests_per_1m_population': '1,405',
#                      'total_cases_per_1m_population': '90',
#                      'total_recovered': '927',
#                      'total_tests': '71,500'},
#                     {'active_cases': '2,112',
#                      'cases': '4,284',
#                      'country_name': 'Finland',
#                      'deaths': '172',
#                      'deaths_per_1m_population': '31',
#                      'new_cases': '155',
#                      'new_deaths': '23',
#                      'region': '',
#                      'serious_critical': '60',
#                      'tests_per_1m_population': '12,814',
#                      'total_cases_per_1m_population': '773',
#                      'total_recovered': '2,000',
#                      'total_tests': '71,000'},
#                     {'active_cases': '3,951',
#                      'cases': '4,186',
#                      'country_name': 'Bangladesh',
#                      'deaths': '127',
#                      'deaths_per_1m_population': '0.8',
#                      'new_cases': '414',
#                      'new_deaths': '7',
#                      'region': '',
#                      'serious_critical': '1',
#                      'tests_per_1m_population': '219',
#                      'total_cases_per_1m_population': '25',
#                      'total_recovered': '108',
#                      'total_tests': '36,090'},
#                     {'active_cases': '2,405',
#                      'cases': '3,953',
#                      'country_name': 'South Africa',
#                      'deaths': '75',
#                      'deaths_per_1m_population': '1',
#                      'new_cases': '318',
#                      'new_deaths': '10',
#                      'region': '',
#                      'serious_critical': '36',
#                      'tests_per_1m_population': '2,421',
#                      'total_cases_per_1m_population': '67',
#                      'total_recovered': '1,473',
#                      'total_tests': '143,570'},
#                     {'active_cases': '2,600',
#                      'cases': '3,891',
#                      'country_name': 'Egypt',
#                      'deaths': '287',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '232',
#                      'new_deaths': '11',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '879',
#                      'total_cases_per_1m_population': '38',
#                      'total_recovered': '1,004',
#                      'total_tests': '90,000'},
#                     {'active_cases': '2,854',
#                      'cases': '3,665',
#                      'country_name': 'Luxembourg',
#                      'deaths': '83',
#                      'deaths_per_1m_population': '133',
#                      'new_cases': '11',
#                      'new_deaths': '3',
#                      'region': '',
#                      'serious_critical': '27',
#                      'tests_per_1m_population': '58,933',
#                      'total_cases_per_1m_population': '5,855',
#                      'total_recovered': '728',
#                      'total_tests': '36,891'},
#                     {'active_cases': '2,957',
#                      'cases': '3,568',
#                      'country_name': 'Morocco',
#                      'deaths': '155',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '122',
#                      'new_deaths': '6',
#                      'region': '',
#                      'serious_critical': '1',
#                      'tests_per_1m_population': '595',
#                      'total_cases_per_1m_population': '97',
#                      'total_recovered': '456',
#                      'total_tests': '21,947'},
#                     {'active_cases': '2,210',
#                      'cases': '3,288',
#                      'country_name': 'Argentina',
#                      'deaths': '159',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '123',
#                      'tests_per_1m_population': '925',
#                      'total_cases_per_1m_population': '73',
#                      'total_recovered': '919',
#                      'total_tests': '41,786'},
#                     {'active_cases': '1,245',
#                      'cases': '3,007',
#                      'country_name': 'Algeria',
#                      'deaths': '407',
#                      'deaths_per_1m_population': '9',
#                      'new_cases': '97',
#                      'new_deaths': '5',
#                      'region': '',
#                      'serious_critical': '40',
#                      'tests_per_1m_population': '148',
#                      'total_cases_per_1m_population': '69',
#                      'total_recovered': '1,355',
#                      'total_tests': '6,500'},
#                     {'active_cases': '2,185',
#                      'cases': '2,926',
#                      'country_name': 'Moldova',
#                      'deaths': '80',
#                      'deaths_per_1m_population': '20',
#                      'new_cases': '148',
#                      'new_deaths': '5',
#                      'region': '',
#                      'serious_critical': '212',
#                      'tests_per_1m_population': '2,916',
#                      'total_cases_per_1m_population': '725',
#                      'total_recovered': '661',
#                      'total_tests': '11,763'},
#                     {'active_cases': '359',
#                      'cases': '2,839',
#                      'country_name': 'Thailand',
#                      'deaths': '50',
#                      'deaths_per_1m_population': '0.7',
#                      'new_cases': '13',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '61',
#                      'tests_per_1m_population': '2,043',
#                      'total_cases_per_1m_population': '41',
#                      'total_recovered': '2,430',
#                      'total_tests': '142,589'},
#                     {'active_cases': '1,761',
#                      'cases': '2,463',
#                      'country_name': 'Greece',
#                      'deaths': '125',
#                      'deaths_per_1m_population': '12',
#                      'new_cases': '55',
#                      'new_deaths': '4',
#                      'region': '',
#                      'serious_critical': '52',
#                      'tests_per_1m_population': '5,684',
#                      'total_cases_per_1m_population': '236',
#                      'total_recovered': '577',
#                      'total_tests': '59,241'},
#                     {'active_cases': '1,887',
#                      'cases': '2,399',
#                      'country_name': 'Kuwait',
#                      'deaths': '14',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '151',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '55',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '562',
#                      'total_recovered': '498',
#                      'total_tests': '0'},
#                     {'active_cases': '1,709',
#                      'cases': '2,289',
#                      'country_name': 'Kazakhstan',
#                      'deaths': '20',
#                      'deaths_per_1m_population': '1',
#                      'new_cases': '154',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '29',
#                      'tests_per_1m_population': '8,175',
#                      'total_cases_per_1m_population': '122',
#                      'total_recovered': '560',
#                      'total_tests': '153,492'},
#                     {'active_cases': '1,655',
#                      'cases': '2,284',
#                      'country_name': 'Hungary',
#                      'deaths': '239',
#                      'deaths_per_1m_population': '25',
#                      'new_cases': '116',
#                      'new_deaths': '14',
#                      'region': '',
#                      'serious_critical': '61',
#                      'tests_per_1m_population': '5,734',
#                      'total_cases_per_1m_population': '236',
#                      'total_recovered': '390',
#                      'total_tests': '55,390'},
#                     {'active_cases': '1,127',
#                      'cases': '2,217',
#                      'country_name': 'Bahrain',
#                      'deaths': '8',
#                      'deaths_per_1m_population': '5',
#                      'new_cases': '190',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '2',
#                      'tests_per_1m_population': '58,787',
#                      'total_cases_per_1m_population': '1,303',
#                      'total_recovered': '1,082',
#                      'total_tests': '100,031'},
#                     {'active_cases': '1,048',
#                      'cases': '1,981',
#                      'country_name': 'Croatia',
#                      'deaths': '50',
#                      'deaths_per_1m_population': '12',
#                      'new_cases': '31',
#                      'new_deaths': '2',
#                      'region': '',
#                      'serious_critical': '19',
#                      'tests_per_1m_population': '7,028',
#                      'total_cases_per_1m_population': '483',
#                      'total_recovered': '883',
#                      'total_tests': '28,853'},
#                     {'active_cases': '270',
#                      'cases': '1,789',
#                      'country_name': 'Iceland',
#                      'deaths': '10',
#                      'deaths_per_1m_population': '29',
#                      'new_cases': '4',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '5',
#                      'tests_per_1m_population': '132,143',
#                      'total_cases_per_1m_population': '5,243',
#                      'total_recovered': '1,509',
#                      'total_tests': '45,093'},
#                     {'active_cases': '1,190',
#                      'cases': '1,758',
#                      'country_name': 'Uzbekistan',
#                      'deaths': '7',
#                      'deaths_per_1m_population': '0.2',
#                      'new_cases': '42',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '8',
#                      'tests_per_1m_population': '6,274',
#                      'total_cases_per_1m_population': '53',
#                      'total_recovered': '561',
#                      'total_tests': '210,000'},
#                     {'active_cases': '1,400',
#                      'cases': '1,716',
#                      'country_name': 'Oman',
#                      'deaths': '9',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '102',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '3',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '336',
#                      'total_recovered': '307',
#                      'total_tests': '0'},
#                     {'active_cases': '423',
#                      'cases': '1,677',
#                      'country_name': 'Iraq',
#                      'deaths': '83',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '46',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '1,613',
#                      'total_cases_per_1m_population': '42',
#                      'total_recovered': '1,171',
#                      'total_tests': '64,882'},
#                     {'active_cases': '1,355',
#                      'cases': '1,592',
#                      'country_name': 'Estonia',
#                      'deaths': '45',
#                      'deaths_per_1m_population': '34',
#                      'new_cases': '33',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '7',
#                      'tests_per_1m_population': '34,059',
#                      'total_cases_per_1m_population': '1,200',
#                      'total_recovered': '192',
#                      'total_tests': '45,181'},
#                     {'active_cases': '580',
#                      'cases': '1,548',
#                      'country_name': 'Azerbaijan',
#                      'deaths': '20',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '30',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '14',
#                      'tests_per_1m_population': '10,674',
#                      'total_cases_per_1m_population': '153',
#                      'total_recovered': '948',
#                      'total_tests': '108,221'},
#                     {'active_cases': '840',
#                      'cases': '1,523',
#                      'country_name': 'Armenia',
#                      'deaths': '24',
#                      'deaths_per_1m_population': '8',
#                      'new_cases': '50',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '10',
#                      'tests_per_1m_population': '5,386',
#                      'total_cases_per_1m_population': '514',
#                      'total_recovered': '659',
#                      'total_tests': '15,960'},
#                     {'active_cases': '370',
#                      'cases': '1,451',
#                      'country_name': 'New Zealand',
#                      'deaths': '16',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '3',
#                      'new_deaths': '2',
#                      'region': '',
#                      'serious_critical': '2',
#                      'tests_per_1m_population': '21,002',
#                      'total_cases_per_1m_population': '301',
#                      'total_recovered': '1,065',
#                      'total_tests': '101,277'},
#                     {'active_cases': '874',
#                      'cases': '1,413',
#                      'country_name': 'Bosnia and Herzegovina',
#                      'deaths': '54',
#                      'deaths_per_1m_population': '16',
#                      'new_cases': '45',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '4',
#                      'tests_per_1m_population': '6,533',
#                      'total_cases_per_1m_population': '431',
#                      'total_recovered': '485',
#                      'total_tests': '21,432'},
#                     {'active_cases': '959',
#                      'cases': '1,398',
#                      'country_name': 'Lithuania',
#                      'deaths': '40',
#                      'deaths_per_1m_population': '15',
#                      'new_cases': '28',
#                      'new_deaths': '2',
#                      'region': '',
#                      'serious_critical': '17',
#                      'tests_per_1m_population': '30,706',
#                      'total_cases_per_1m_population': '514',
#                      'total_recovered': '399',
#                      'total_tests': '83,591'},
#                     {'active_cases': '1,076',
#                      'cases': '1,366',
#                      'country_name': 'Slovenia',
#                      'deaths': '79',
#                      'deaths_per_1m_population': '38',
#                      'new_cases': '13',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '23',
#                      'tests_per_1m_population': '21,984',
#                      'total_cases_per_1m_population': '657',
#                      'total_recovered': '211',
#                      'total_tests': '45,703'},
#                     {'active_cases': '623',
#                      'cases': '1,334',
#                      'country_name': 'Cameroon',
#                      'deaths': '43',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '171',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '33',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '50',
#                      'total_recovered': '668',
#                      'total_tests': '0'},
#                     {'active_cases': '1,022',
#                      'cases': '1,325',
#                      'country_name': 'Slovakia',
#                      'deaths': '15',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '81',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '9',
#                      'tests_per_1m_population': '10,517',
#                      'total_cases_per_1m_population': '243',
#                      'total_recovered': '288',
#                      'total_tests': '57,421'},
#                     {'active_cases': '943',
#                      'cases': '1,300',
#                      'country_name': 'North Macedonia',
#                      'deaths': '56',
#                      'deaths_per_1m_population': '27',
#                      'new_cases': '41',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '14',
#                      'tests_per_1m_population': '6,551',
#                      'total_cases_per_1m_population': '624',
#                      'total_recovered': '301',
#                      'total_tests': '13,649'},
#                     {'active_cases': '1,058',
#                      'cases': '1,279',
#                      'country_name': 'Afghanistan',
#                      'deaths': '42',
#                      'deaths_per_1m_population': '1',
#                      'new_cases': '103',
#                      'new_deaths': '2',
#                      'region': '',
#                      'serious_critical': '7',
#                      'tests_per_1m_population': '165',
#                      'total_cases_per_1m_population': '33',
#                      'total_recovered': '179',
#                      'total_tests': '6,422'},
#                     {'active_cases': '827',
#                      'cases': '1,235',
#                      'country_name': 'Cuba',
#                      'deaths': '43',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '46',
#                      'new_deaths': '3',
#                      'region': '',
#                      'serious_critical': '14',
#                      'tests_per_1m_population': '3,023',
#                      'total_cases_per_1m_population': '109',
#                      'total_recovered': '365',
#                      'total_tests': '34,243'},
#                     {'active_cases': '1,046',
#                      'cases': '1,154',
#                      'country_name': 'Ghana',
#                      'deaths': '9',
#                      'deaths_per_1m_population': '0.3',
# ...
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '1,982',
#                      'total_cases_per_1m_population': '82',
#                      'total_recovered': '15',
#                      'total_tests': '364'},
#                     {'active_cases': '2',
#                      'cases': '14',
#                      'country_name': 'Curaçao',
#                      'deaths': '1',
#                      'deaths_per_1m_population': '6',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '1,853',
#                      'total_cases_per_1m_population': '85',
#                      'total_recovered': '11',
#                      'total_tests': '304'},
#                     {'active_cases': '10',
#                      'cases': '13',
#                      'country_name': 'St. Vincent Grenadines',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '892',
#                      'total_cases_per_1m_population': '117',
#                      'total_recovered': '3',
#                      'total_tests': '99'},
#                     {'active_cases': '1',
#                      'cases': '12',
#                      'country_name': 'Falkland Islands',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '1',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '96,839',
#                      'total_cases_per_1m_population': '3,448',
#                      'total_recovered': '11',
#                      'total_tests': '337'},
#                     {'active_cases': '1',
#                      'cases': '11',
#                      'country_name': 'Nicaragua',
#                      'deaths': '3',
#                      'deaths_per_1m_population': '0.5',
#                      'new_cases': '1',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '2',
#                      'total_recovered': '7',
#                      'total_tests': '0'},
#                     {'active_cases': '6',
#                      'cases': '11',
#                      'country_name': 'Burundi',
#                      'deaths': '1',
#                      'deaths_per_1m_population': '0.08',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '24',
#                      'total_cases_per_1m_population': '0.9',
#                      'total_recovered': '4',
#                      'total_tests': '284'},
#                     {'active_cases': '6',
#                      'cases': '11',
#                      'country_name': 'Turks and Caicos',
#                      'deaths': '1',
#                      'deaths_per_1m_population': '26',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '2,144',
#                      'total_cases_per_1m_population': '284',
#                      'total_recovered': '4',
#                      'total_tests': '83'},
#                     {'active_cases': '0',
#                      'cases': '11',
#                      'country_name': 'Greenland',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '20,257',
#                      'total_cases_per_1m_population': '194',
#                      'total_recovered': '11',
#                      'total_tests': '1,150'},
#                     {'active_cases': '9',
#                      'cases': '11',
#                      'country_name': 'Montserrat',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '1',
#                      'tests_per_1m_population': '7,212',
#                      'total_cases_per_1m_population': '2,204',
#                      'total_recovered': '2',
#                      'total_tests': '36'},
#                     {'active_cases': '5',
#                      'cases': '11',
#                      'country_name': 'Seychelles',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '112',
#                      'total_recovered': '6',
#                      'total_tests': '0'},
#                     {'active_cases': '7',
#                      'cases': '10',
#                      'country_name': 'Gambia',
#                      'deaths': '1',
#                      'deaths_per_1m_population': '0.4',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '131',
#                      'total_cases_per_1m_population': '4',
#                      'total_recovered': '2',
#                      'total_tests': '316'},
#                     {'active_cases': '3',
#                      'cases': '10',
#                      'country_name': 'Suriname',
#                      'deaths': '1',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '689',
#                      'total_cases_per_1m_population': '17',
#                      'total_recovered': '6',
#                      'total_tests': '404'},
#                     {'active_cases': '7',
#                      'cases': '9',
#                      'country_name': 'MS Zaandam',
#                      'deaths': '2',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '0',
#                      'total_recovered': '0',
#                      'total_tests': '0'},
#                     {'active_cases': '7',
#                      'cases': '9',
#                      'country_name': 'Vatican City',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '11,236',
#                      'total_recovered': '2',
#                      'total_tests': '0'},
#                     {'active_cases': '8',
#                      'cases': '8',
#                      'country_name': 'Papua New Guinea',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '68',
#                      'total_cases_per_1m_population': '0.9',
#                      'total_recovered': '0',
#                      'total_tests': '604'},
#                     {'active_cases': '4',
#                      'cases': '7',
#                      'country_name': 'Bhutan',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '11,603',
#                      'total_cases_per_1m_population': '9',
#                      'total_recovered': '3',
#                      'total_tests': '8,953'},
#                     {'active_cases': '0',
#                      'cases': '7',
#                      'country_name': 'Mauritania',
#                      'deaths': '1',
#                      'deaths_per_1m_population': '0.2',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '208',
#                      'total_cases_per_1m_population': '2',
#                      'total_recovered': '6',
#                      'total_tests': '969'},
#                     {'active_cases': '0',
#                      'cases': '6',
#                      'country_name': 'St. Barth',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '607',
#                      'total_recovered': '6',
#                      'total_tests': '0'},
#                     {'active_cases': '1',
#                      'cases': '6',
#                      'country_name': 'Western Sahara',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '10',
#                      'total_recovered': '5',
#                      'total_tests': '0'},
#                     {'active_cases': '1',
#                      'cases': '5',
#                      'country_name': 'British Virgin Islands',
#                      'deaths': '1',
#                      'deaths_per_1m_population': '33',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '165',
#                      'total_recovered': '3',
#                      'total_tests': '0'},
#                     {'active_cases': '5',
#                      'cases': '5',
#                      'country_name': 'Caribbean Netherlands',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '4,195',
#                      'total_cases_per_1m_population': '191',
#                      'total_recovered': '0',
#                      'total_tests': '110'},
#                     {'active_cases': '4',
#                      'cases': '4',
#                      'country_name': 'Sao Tome and Principe',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '87',
#                      'total_cases_per_1m_population': '18',
#                      'total_recovered': '0',
#                      'total_tests': '19'},
#                     {'active_cases': '4',
#                      'cases': '4',
#                      'country_name': 'South Sudan',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '0.4',
#                      'total_recovered': '0',
#                      'total_tests': '0'},
#                     {'active_cases': '2',
#                      'cases': '3',
#                      'country_name': 'Anguilla',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '200',
#                      'total_recovered': '1',
#                      'total_tests': '0'},
#                     {'active_cases': '1',
#                      'cases': '1',
#                      'country_name': 'Saint Pierre Miquelon',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '173',
#                      'total_recovered': '0',
#                      'total_tests': '0'},
#                     {'active_cases': '1',
#                      'cases': '1',
#                      'country_name': 'Yemen',
#                      'deaths': '0',
#                      'deaths_per_1m_population': '0',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '0.03',
#                      'total_recovered': '0',
#                      'total_tests': '0'}],
#  'statistic_taken_at': '2020-04-23 23:58:01',
#  'world_total': {'active_cases': '1,779,637',
#                  'deaths_per_1m_population': '24.4',
#                  'new_cases': '83,210',
#                  'new_deaths': '6,331',
#                  'serious_critical': '58,678',
#                  'statistic_taken_at': '2020-04-23 23:58:01',
#                  'total_cases': '2,714,995',
#                  'total_cases_per_1m_population': '348',
#                  'total_deaths': '190,397',
#                  'total_recovered': '744,961'}}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-bf9edecb0e11> in <module>
#      15
#      16 # create for loop to get each result from countries stat which is the main key of the JSON
# ---> 17 for key in results["countries_stat"]:
#      18     print(key["country_name"])
#      19
#
# NameError: name 'results' is not defined

# %%
results = response.json()
# print(results["countries_stat"])

# %%
# create a DataFrame from scratch (temporary to test)
pd.DataFrame(columns=["country_name"])

# create variable to hold the value belonging to each key in the dataset
countries = []
cases = []
deaths = []
active_cases = []
new_cases = []
new_deaths = []
total_recovered = []
serious_critical = []
deaths_per_1m_population = []
total_cases_per_1m_population = []

# total_tests = []

# for loop to store the data for each key
for key in results["countries_stat"]:
    countries.append(key["country_name"])
    cases.append(key["cases"])
    deaths.append(key["deaths"])
    new_deaths.append(key["new_deaths"])
    new_cases.append(key["new_cases"])
    active_cases.append(key["active_cases"])
    total_recovered.append(key["total_recovered"])
    serious_critical.append(key["serious_critical"])
    deaths_per_1m_population.append(key["deaths_per_1m_population"])
    total_cases_per_1m_population.append(key["total_cases_per_1m_population"])
    #total_tests.append(key["total_tests"])
    
# print(countries)

# %%
# Store dataframe into variable permanent

data = pd.DataFrame(columns=["Country", "Total Cases", "Total Deaths", "New Deaths", "New Cases", "Active Cases", "Total Recovered", "Serious Critical", "Deaths Per 1m_population", "Total Cases Per 1m_population"])
data["Country"] = countries
data["Total Cases"] = cases
data["Total Deaths"] = deaths
data["New Deaths"] = new_deaths
data["New Cases"] = new_cases
data["Active Cases"] = active_cases
data["Total Recovered"] = total_recovered
data["Serious Critical"] = serious_critical
data["Deaths Per 1m_population"] = deaths_per_1m_population
data["Total Cases Per 1m_population"] = total_cases_per_1m_population
# data['Total tests'] = total_tests
#data.head(10).style.set_table_styles([{'selector':'','props':[('border','4px solid #7a7')]}])

data.head(10).style.set_table_styles([{'selector':'','props':[('border','4px solid #7a7')]}])
# Out:
# <style  type="text/css" >
#     #T_9c085ec6_85c1_11ea_910a_b46bfcdeb885  {
#           border: 4px solid #7a7;
#     }</style><table id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country</th>        <th class="col_heading level0 col1" >Total Cases</th>        <th class="col_heading level0 col2" >Total Deaths</th>        <th class="col_heading level0 col3" >New Deaths</th>        <th class="col_heading level0 col4" >New Cases</th>        <th class="col_heading level0 col5" >Active Cases</th>        <th class="col_heading level0 col6" >Total Recovered</th>        <th class="col_heading level0 col7" >Serious Critical</th>        <th class="col_heading level0 col8" >Deaths Per 1m_population</th>        <th class="col_heading level0 col9" >Total Cases Per 1m_population</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row0_col0" class="data row0 col0" >USA</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row0_col1" class="data row0 col1" >878,974</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row0_col2" class="data row0 col2" >49,754</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row0_col3" class="data row0 col3" >2,095</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row0_col4" class="data row0 col4" >30,257</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row0_col5" class="data row0 col5" >743,596</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row0_col6" class="data row0 col6" >85,624</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row0_col7" class="data row0 col7" >14,997</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row0_col8" class="data row0 col8" >150</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row0_col9" class="data row0 col9" >2,655</td>
#             </tr>
#             <tr>
#                         <th id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row1_col0" class="data row1 col0" >Spain</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row1_col1" class="data row1 col1" >213,024</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row1_col2" class="data row1 col2" >22,157</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row1_col3" class="data row1 col3" >440</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row1_col4" class="data row1 col4" >4,635</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row1_col5" class="data row1 col5" >101,617</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row1_col6" class="data row1 col6" >89,250</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row1_col7" class="data row1 col7" >7,705</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row1_col8" class="data row1 col8" >474</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row1_col9" class="data row1 col9" >4,556</td>
#             </tr>
#             <tr>
#                         <th id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row2_col0" class="data row2 col0" >Italy</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row2_col1" class="data row2 col1" >189,973</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row2_col2" class="data row2 col2" >25,549</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row2_col3" class="data row2 col3" >464</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row2_col4" class="data row2 col4" >2,646</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row2_col5" class="data row2 col5" >106,848</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row2_col6" class="data row2 col6" >57,576</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row2_col7" class="data row2 col7" >2,267</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row2_col8" class="data row2 col8" >423</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row2_col9" class="data row2 col9" >3,142</td>
#             </tr>
#             <tr>
#                         <th id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row3_col0" class="data row3 col0" >France</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row3_col1" class="data row3 col1" >158,183</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row3_col2" class="data row3 col2" >21,856</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row3_col3" class="data row3 col3" >516</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row3_col4" class="data row3 col4" >2,239</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row3_col5" class="data row3 col5" >94,239</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row3_col6" class="data row3 col6" >42,088</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row3_col7" class="data row3 col7" >5,053</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row3_col8" class="data row3 col8" >335</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row3_col9" class="data row3 col9" >2,423</td>
#             </tr>
#             <tr>
#                         <th id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row4_col0" class="data row4 col0" >Germany</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row4_col1" class="data row4 col1" >153,129</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row4_col2" class="data row4 col2" >5,575</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row4_col3" class="data row4 col3" >260</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row4_col4" class="data row4 col4" >2,481</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row4_col5" class="data row4 col5" >44,254</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row4_col6" class="data row4 col6" >103,300</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row4_col7" class="data row4 col7" >2,908</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row4_col8" class="data row4 col8" >67</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row4_col9" class="data row4 col9" >1,828</td>
#             </tr>
#             <tr>
#                         <th id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row5_col0" class="data row5 col0" >UK</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row5_col1" class="data row5 col1" >138,078</td>
#                         <td id="T_9c085ec6_85c1_11ea_910a_b46bfcdeb885row5_col2" class="data row5 col2" >18,738</td>

# %%
# WORLD TOTAL 

url2 = "https://covid-19-data.p.rapidapi.com/totals"

querystring = {"format":"json"}

headers = {
    'x-rapidapi-host': "covid-19-data.p.rapidapi.com",
    'x-rapidapi-key': "mNTV7WxSsqmshvTYBNiZHBqh6x8Wp1gRwifjsnRj6RKhp8LeTb"
    }

response = requests.request("GET", url2, headers=headers, params=querystring)

# pprint(response.text)


pprint(response.json())

# convert JSON into a python dictorinary format in order to read/loop through it.
# results = response.json()

# Print result to confirm
# pprint(results["countries_stat"])
world_df = pd.DataFrame
# Out:
# [{'confirmed': 2725696,
#   'critical': 58678,
#   'deaths': 190928,
#   'recovered': 755547}]

# %%
# Make fake dataset
height = [184840, 56679, 728331, 2645998]
bars = ('Deaths', 'Critical', 'Recovered', 'Confirmed')
y_pos = np.arange(len(bars))
 
# Create horizontal bars
plt.barh(y_pos, height, color=['black', 'red', 'green', 'blue'])
 
# Create names on the y-axis
plt.yticks(y_pos, bars)
 
 # Set textual properties
plt.title("World Total")
# plt.ylabel("Number of Battles Participated In")
plt.xlabel("Count")

# plt.bar(y_pos, height, color=['black', 'red', 'green', 'blue', 'cyan'])

# Show graphic
plt.show()

# %%
#  Monthly Trend

# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv

# Save path to data set in a variable
monthly_csv = "Monthly.csv"
monthly_df = pd.read_csv(monthly_csv)
monthly_df
# Out:
#   Month  Confirmed  Recovered  Deaths   Active
# 0   Jan       8235        143     171     7921
# 1   Feb      85308      39772    2935    42601
# 2   Mar     857256     169394   42105   453032
# 3   Apr    2623415     709694  183027  1730694
