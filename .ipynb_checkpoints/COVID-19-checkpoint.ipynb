# %%
import json
import requests
from pprint import pprint
#from config import api_key
import sys
from pygments import highlight, lexers, formatters
import pandas as pd
#from flask import jsonify
import gmaps
import gmaps.datasets
gmaps.configure(api_key = 'AIzaSyAdL7MCWd9I5ePkmQVHAAgt_wJnDrjxhsc')

# %%
## Data from https://rapidapi.com/spamakashrajtech/api/corona-virus-world-and-india-data?endpoint=apiendpoint_86a51f27-421a-4078-a9cc-e459e1122d5d 

# make a call to the URL 
url = "https://corona-virus-world-and-india-data.p.rapidapi.com/api"

# pass key and host login
headers = {
    'x-rapidapi-host': "corona-virus-world-and-india-data.p.rapidapi.com",
    'x-rapidapi-key': "mNTV7WxSsqmshvTYBNiZHBqh6x8Wp1gRwifjsnRj6RKhp8LeTb"
    }

# Store the information from the GET call into the "response" variable
response = requests.request("GET", url, headers=headers)
pprint(response.json())

# convert JSON into a python dictorinary format in order to read/loop through it.
results = response.json()

# Print result to confirm
pprint(results["countries_stat"])

# create for loop to get each result from countries stat which is the main key of the JSON
for key in results["countries_stat"]:
    print(key['country_name'])
# Out:
# {'countries_stat': [{'active_cases': '688,518',
#                      'cases': '816,385',
#                      'country_name': 'USA',
#                      'deaths': '45,174',
#                      'deaths_per_1m_population': '136',
#                      'new_cases': '23,626',
#                      'new_deaths': '2,660',
#                      'region': '',
#                      'serious_critical': '14,016',
#                      'tests_per_1m_population': '12,634',
#                      'total_cases_per_1m_population': '2,466',
#                      'total_recovered': '82,693',
#                      'total_tests': '4,182,037'},
#                     {'active_cases': '100,382',
#                      'cases': '204,178',
#                      'country_name': 'Spain',
#                      'deaths': '21,282',
#                      'deaths_per_1m_population': '455',
#                      'new_cases': '3,968',
#                      'new_deaths': '430',
#                      'region': '',
#                      'serious_critical': '7,705',
#                      'tests_per_1m_population': '19,896',
#                      'total_cases_per_1m_population': '4,367',
#                      'total_recovered': '82,514',
#                      'total_tests': '930,230'},
#                     {'active_cases': '107,709',
#                      'cases': '183,957',
#                      'country_name': 'Italy',
#                      'deaths': '24,648',
#                      'deaths_per_1m_population': '408',
#                      'new_cases': '2,729',
#                      'new_deaths': '534',
#                      'region': '',
#                      'serious_critical': '2,471',
#                      'tests_per_1m_population': '23,985',
#                      'total_cases_per_1m_population': '3,043',
#                      'total_recovered': '51,600',
#                      'total_tests': '1,450,150'},
#                     {'active_cases': '98,073',
#                      'cases': '158,050',
#                      'country_name': 'France',
#                      'deaths': '20,796',
#                      'deaths_per_1m_population': '319',
#                      'new_cases': '2,667',
#                      'new_deaths': '531',
#                      'region': '',
#                      'serious_critical': '5,433',
#                      'tests_per_1m_population': '7,103',
#                      'total_cases_per_1m_population': '2,421',
#                      'total_recovered': '39,181',
#                      'total_tests': '463,662'},
#                     {'active_cases': '48,058',
#                      'cases': '148,291',
#                      'country_name': 'Germany',
#                      'deaths': '5,033',
#                      'deaths_per_1m_population': '60',
#                      'new_cases': '1,226',
#                      'new_deaths': '171',
#                      'region': '',
#                      'serious_critical': '2,889',
#                      'tests_per_1m_population': '20,629',
#                      'total_cases_per_1m_population': '1,770',
#                      'total_recovered': '95,200',
#                      'total_tests': '1,728,357'},
#                     {'active_cases': '111,363',
#                      'cases': '129,044',
#                      'country_name': 'UK',
#                      'deaths': '17,337',
#                      'deaths_per_1m_population': '255',
#                      'new_cases': '4,301',
#                      'new_deaths': '828',
#                      'region': '',
#                      'serious_critical': '1,559',
#                      'tests_per_1m_population': '7,886',
#                      'total_cases_per_1m_population': '1,901',
#                      'total_recovered': 'N/A',
#                      'total_tests': '535,342'},
#                     {'active_cases': '78,414',
#                      'cases': '95,591',
#                      'country_name': 'Turkey',
#                      'deaths': '2,259',
#                      'deaths_per_1m_population': '27',
#                      'new_cases': '4,611',
#                      'new_deaths': '119',
#                      'region': '',
#                      'serious_critical': '1,865',
#                      'tests_per_1m_population': '8,459',
#                      'total_cases_per_1m_population': '1,133',
#                      'total_recovered': '14,918',
#                      'total_tests': '713,409'},
#                     {'active_cases': '18,540',
#                      'cases': '84,802',
#                      'country_name': 'Iran',
#                      'deaths': '5,297',
#                      'deaths_per_1m_population': '63',
#                      'new_cases': '1,297',
#                      'new_deaths': '88',
#                      'region': '',
#                      'serious_critical': '3,357',
#                      'tests_per_1m_population': '4,354',
#                      'total_cases_per_1m_population': '1,010',
#                      'total_recovered': '60,965',
#                      'total_tests': '365,723'},
#                     {'active_cases': '1,003',
#                      'cases': '82,758',
#                      'country_name': 'China',
#                      'deaths': '4,632',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '11',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '82',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '57',
#                      'total_recovered': '77,123',
#                      'total_tests': '0'},
#                     {'active_cases': '48,434',
#                      'cases': '52,763',
#                      'country_name': 'Russia',
#                      'deaths': '456',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '5,642',
#                      'new_deaths': '51',
#                      'region': '',
#                      'serious_critical': '700',
#                      'tests_per_1m_population': '14,682',
#                      'total_cases_per_1m_population': '362',
#                      'total_recovered': '3,873',
#                      'total_tests': '2,142,604'},
#                     {'active_cases': '17,347',
#                      'cases': '43,079',
#                      'country_name': 'Brazil',
#                      'deaths': '2,741',
#                      'deaths_per_1m_population': '13',
#                      'new_cases': '2,336',
#                      'new_deaths': '154',
#                      'region': '',
#                      'serious_critical': '8,318',
#                      'tests_per_1m_population': '1,373',
#                      'total_cases_per_1m_population': '203',
#                      'total_recovered': '22,991',
#                      'total_tests': '291,922'},
#                     {'active_cases': '25,956',
#                      'cases': '40,956',
#                      'country_name': 'Belgium',
#                      'deaths': '5,998',
#                      'deaths_per_1m_population': '518',
#                      'new_cases': '973',
#                      'new_deaths': '170',
#                      'region': '',
#                      'serious_critical': '1,079',
#                      'tests_per_1m_population': '14,419',
#                      'total_cases_per_1m_population': '3,534',
#                      'total_recovered': '9,002',
#                      'total_tests': '167,110'},
#                     {'active_cases': '23,446',
#                      'cases': '38,422',
#                      'country_name': 'Canada',
#                      'deaths': '1,833',
#                      'deaths_per_1m_population': '49',
#                      'new_cases': '1,593',
#                      'new_deaths': '143',
#                      'region': '',
#                      'serious_critical': '557',
#                      'tests_per_1m_population': '14,995',
#                      'total_cases_per_1m_population': '1,018',
#                      'total_recovered': '13,143',
#                      'total_tests': '565,931'},
#                     {'active_cases': '29,968',
#                      'cases': '34,134',
#                      'country_name': 'Netherlands',
#                      'deaths': '3,916',
#                      'deaths_per_1m_population': '229',
#                      'new_cases': '729',
#                      'new_deaths': '165',
#                      'region': '',
#                      'serious_critical': '1,087',
#                      'tests_per_1m_population': '10,004',
#                      'total_cases_per_1m_population': '1,992',
#                      'total_recovered': 'N/A',
#                      'total_tests': '171,415'},
#                     {'active_cases': '7,185',
#                      'cases': '28,063',
#                      'country_name': 'Switzerland',
#                      'deaths': '1,478',
#                      'deaths_per_1m_population': '171',
#                      'new_cases': '119',
#                      'new_deaths': '49',
#                      'region': '',
#                      'serious_critical': '386',
#                      'tests_per_1m_population': '26,293',
#                      'total_cases_per_1m_population': '3,243',
#                      'total_recovered': '19,400',
#                      'total_tests': '227,554'},
#                     {'active_cases': '19,700',
#                      'cases': '21,379',
#                      'country_name': 'Portugal',
#                      'deaths': '762',
#                      'deaths_per_1m_population': '75',
#                      'new_cases': '516',
#                      'new_deaths': '27',
#                      'region': '',
#                      'serious_critical': '213',
#                      'tests_per_1m_population': '26,672',
#                      'total_cases_per_1m_population': '2,097',
#                      'total_recovered': '917',
#                      'total_tests': '271,962'},
#                     {'active_cases': '15,460',
#                      'cases': '20,080',
#                      'country_name': 'India',
#                      'deaths': '645',
#                      'deaths_per_1m_population': '0.5',
#                      'new_cases': '1,541',
#                      'new_deaths': '53',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '325',
#                      'total_cases_per_1m_population': '15',
#                      'total_recovered': '3,975',
#                      'total_tests': '447,812'},
#                     {'active_cases': '10,371',
#                      'cases': '17,837',
#                      'country_name': 'Peru',
#                      'deaths': '484',
#                      'deaths_per_1m_population': '15',
#                      'new_cases': '1,512',
#                      'new_deaths': '39',
#                      'region': '',
#                      'serious_critical': '380',
#                      'tests_per_1m_population': '4,723',
#                      'total_cases_per_1m_population': '541',
#                      'total_recovered': '6,982',
#                      'total_tests': '155,724'},
#                     {'active_cases': '6,077',
#                      'cases': '16,040',
#                      'country_name': 'Ireland',
#                      'deaths': '730',
#                      'deaths_per_1m_population': '148',
#                      'new_cases': '388',
#                      'new_deaths': '43',
#                      'region': '',
#                      'serious_critical': '315',
#                      'tests_per_1m_population': '22,598',
#                      'total_cases_per_1m_population': '3,248',
#                      'total_recovered': '9,233',
#                      'total_tests': '111,584'},
#                     {'active_cases': '13,007',
#                      'cases': '15,322',
#                      'country_name': 'Sweden',
#                      'deaths': '1,765',
#                      'deaths_per_1m_population': '175',
#                      'new_cases': '545',
#                      'new_deaths': '185',
#                      'region': '',
#                      'serious_critical': '515',
#                      'tests_per_1m_population': '9,357',
#                      'total_cases_per_1m_population': '1,517',
#                      'total_recovered': '550',
#                      'total_tests': '94,500'},
#                     {'active_cases': '3,411',
#                      'cases': '14,873',
#                      'country_name': 'Austria',
#                      'deaths': '491',
#                      'deaths_per_1m_population': '55',
#                      'new_cases': '78',
#                      'new_deaths': '21',
#                      'region': '',
#                      'serious_critical': '196',
#                      'tests_per_1m_population': '20,987',
#                      'total_cases_per_1m_population': '1,651',
#                      'total_recovered': '10,971',
#                      'total_tests': '189,018'},
#                     {'active_cases': '9,251',
#                      'cases': '13,942',
#                      'country_name': 'Israel',
#                      'deaths': '184',
#                      'deaths_per_1m_population': '21',
#                      'new_cases': '229',
#                      'new_deaths': '7',
#                      'region': '',
#                      'serious_critical': '139',
#                      'tests_per_1m_population': '27,763',
#                      'total_cases_per_1m_population': '1,611',
#                      'total_recovered': '4,507',
#                      'total_tests': '240,303'},
#                     {'active_cases': '9,882',
#                      'cases': '11,631',
#                      'country_name': 'Saudi Arabia',
#                      'deaths': '109',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '1,147',
#                      'new_deaths': '6',
#                      'region': '',
#                      'serious_critical': '81',
#                      'tests_per_1m_population': '14,362',
#                      'total_cases_per_1m_population': '334',
#                      'total_recovered': '1,640',
#                      'total_tests': '500,000'},
#                     {'active_cases': '9,633',
#                      'cases': '11,135',
#                      'country_name': 'Japan',
#                      'deaths': '263',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '0',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '217',
#                      'tests_per_1m_population': '923',
#                      'total_cases_per_1m_population': '88',
#                      'total_recovered': '1,239',
#                      'total_tests': '116,725'},
#                     {'active_cases': '5,716',
#                      'cases': '10,832',
#                      'country_name': 'Chile',
#                      'deaths': '147',
#                      'deaths_per_1m_population': '8',
#                      'new_cases': '325',
#                      'new_deaths': '8',
#                      'region': '',
#                      'serious_critical': '392',
#                      'tests_per_1m_population': '6,401',
#                      'total_cases_per_1m_population': '567',
#                      'total_recovered': '4,969',
#                      'total_tests': '122,357'},
#                     {'active_cases': '2,233',
#                      'cases': '10,683',
#                      'country_name': 'S. Korea',
#                      'deaths': '237',
#                      'deaths_per_1m_population': '5',
#                      'new_cases': '9',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '55',
#                      'tests_per_1m_population': '11,138',
#                      'total_cases_per_1m_population': '208',
#                      'total_recovered': '8,213',
#                      'total_tests': '571,014'},
#                     {'active_cases': '8,671',
#                      'cases': '10,398',
#                      'country_name': 'Ecuador',
#                      'deaths': '520',
#                      'deaths_per_1m_population': '29',
#                      'new_cases': '270',
#                      'new_deaths': '13',
#                      'region': '',
#                      'serious_critical': '137',
#                      'tests_per_1m_population': '1,892',
#                      'total_cases_per_1m_population': '589',
#                      'total_recovered': '1,207',
#                      'total_tests': '33,389'},
#                     {'active_cases': '8,158',
#                      'cases': '9,856',
#                      'country_name': 'Poland',
#                      'deaths': '401',
#                      'deaths_per_1m_population': '11',
#                      'new_cases': '263',
#                      'new_deaths': '21',
#                      'region': '',
#                      'serious_critical': '160',
#                      'tests_per_1m_population': '5,928',
#                      'total_cases_per_1m_population': '260',
#                      'total_recovered': '1,297',
#                      'total_tests': '224,355'},
#                     {'active_cases': '7,291',
#                      'cases': '9,565',
#                      'country_name': 'Pakistan',
#                      'deaths': '201',
#                      'deaths_per_1m_population': '0.9',
#                      'new_cases': '673',
#                      'new_deaths': '25',
#                      'region': '',
#                      'serious_critical': '46',
#                      'tests_per_1m_population': '506',
#                      'total_cases_per_1m_population': '43',
#                      'total_recovered': '2,073',
#                      'total_tests': '111,806'},
#                     {'active_cases': '6,591',
#                      'cases': '9,242',
#                      'country_name': 'Romania',
#                      'deaths': '498',
#                      'deaths_per_1m_population': '26',
#                      'new_cases': '306',
#                      'new_deaths': '20',
#                      'region': '',
#                      'serious_critical': '245',
#                      'tests_per_1m_population': '5,279',
#                      'total_cases_per_1m_population': '480',
#                      'total_recovered': '2,153',
#                      'total_tests': '101,552'},
#                     {'active_cases': '8,275',
#                      'cases': '9,125',
#                      'country_name': 'Singapore',
#                      'deaths': '11',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '1,111',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '23',
#                      'tests_per_1m_population': '16,203',
#                      'total_cases_per_1m_population': '1,560',
#                      'total_recovered': '839',
#                      'total_tests': '94,796'},
#                     {'active_cases': '5,433',
#                      'cases': '8,772',
#                      'country_name': 'Mexico',
#                      'deaths': '712',
#                      'deaths_per_1m_population': '6',
#                      'new_cases': '511',
#                      'new_deaths': '26',
#                      'region': '',
#                      'serious_critical': '378',
#                      'tests_per_1m_population': '384',
#                      'total_cases_per_1m_population': '68',
#                      'total_recovered': '2,627',
#                      'total_tests': '49,570'},
#                     {'active_cases': '6,266',
#                      'cases': '7,755',
#                      'country_name': 'UAE',
#                      'deaths': '46',
#                      'deaths_per_1m_population': '5',
#                      'new_cases': '490',
#                      'new_deaths': '3',
#                      'region': '',
#                      'serious_critical': '1',
#                      'tests_per_1m_population': '79,875',
#                      'total_cases_per_1m_population': '784',
#                      'total_recovered': '1,443',
#                      'total_tests': '790,000'},
#                     {'active_cases': '2,625',
#                      'cases': '7,695',
#                      'country_name': 'Denmark',
#                      'deaths': '370',
#                      'deaths_per_1m_population': '64',
#                      'new_cases': '180',
#                      'new_deaths': '6',
#                      'region': '',
#                      'serious_critical': '81',
#                      'tests_per_1m_population': '17,358',
#                      'total_cases_per_1m_population': '1,329',
#                      'total_recovered': '4,700',
#                      'total_tests': '100,543'},
#                     {'active_cases': '6,977',
#                      'cases': '7,191',
#                      'country_name': 'Norway',
#                      'deaths': '182',
#                      'deaths_per_1m_population': '34',
#                      'new_cases': '35',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '58',
#                      'tests_per_1m_population': '26,798',
#                      'total_cases_per_1m_population': '1,326',
#                      'total_recovered': '32',
#                      'total_tests': '145,279'},
#                     {'active_cases': '5,677',
#                      'cases': '7,135',
#                      'country_name': 'Indonesia',
#                      'deaths': '616',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '375',
#                      'new_deaths': '26',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '184',
#                      'total_cases_per_1m_population': '26',
#                      'total_recovered': '842',
#                      'total_tests': '50,370'},
#                     {'active_cases': '5,079',
#                      'cases': '7,033',
#                      'country_name': 'Czechia',
#                      'deaths': '201',
#                      'deaths_per_1m_population': '19',
#                      'new_cases': '133',
#                      'new_deaths': '7',
#                      'region': '',
#                      'serious_critical': '75',
#                      'tests_per_1m_population': '16,679',
#                      'total_cases_per_1m_population': '657',
#                      'total_recovered': '1,753',
#                      'total_tests': '178,617'},
#                     {'active_cases': '5,783',
#                      'cases': '6,890',
#                      'country_name': 'Serbia',
#                      'deaths': '130',
#                      'deaths_per_1m_population': '15',
#                      'new_cases': '260',
#                      'new_deaths': '5',
#                      'region': '',
#                      'serious_critical': '101',
#                      'tests_per_1m_population': '5,191',
#                      'total_cases_per_1m_population': '789',
#                      'total_recovered': '977',
#                      'total_tests': '45,355'},
#                     {'active_cases': '6,091',
#                      'cases': '6,723',
#                      'country_name': 'Belarus',
#                      'deaths': '55',
#                      'deaths_per_1m_population': '6',
#                      'new_cases': '459',
#                      'new_deaths': '4',
#                      'region': '',
#                      'serious_critical': '92',
#                      'tests_per_1m_population': '11,487',
#                      'total_cases_per_1m_population': '711',
#                      'total_recovered': '577',
#                      'total_tests': '108,545'},
#                     {'active_cases': '1,889',
#                      'cases': '6,645',
#                      'country_name': 'Australia',
#                      'deaths': '71',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '20',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '49',
#                      'tests_per_1m_population': '17,216',
#                      'total_cases_per_1m_population': '261',
#                      'total_recovered': '4,685',
#                      'total_tests': '439,000'},
#                     {'active_cases': '5,508',
#                      'cases': '6,599',
#                      'country_name': 'Philippines',
#                      'deaths': '437',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '140',
#                      'new_deaths': '9',
#                      'region': '',
#                      'serious_critical': '1',
#                      'tests_per_1m_population': '592',
#                      'total_cases_per_1m_population': '60',
#                      'total_recovered': '654',
#                      'total_tests': '64,845'},
#                     {'active_cases': '5,910',
#                      'cases': '6,533',
#                      'country_name': 'Qatar',
#                      'deaths': '9',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '518',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '37',
#                      'tests_per_1m_population': '23,160',
#                      'total_cases_per_1m_population': '2,268',
#                      'total_recovered': '614',
#                      'total_tests': '66,725'},
#                     {'active_cases': '5,597',
#                      'cases': '6,125',
#                      'country_name': 'Ukraine',
#                      'deaths': '161',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '415',
#                      'new_deaths': '10',
#                      'region': '',
#                      'serious_critical': '45',
#                      'tests_per_1m_population': '1,418',
#                      'total_cases_per_1m_population': '140',
#                      'total_recovered': '367',
#                      'total_tests': '61,997'},
#                     {'active_cases': '2,041',
#                      'cases': '5,482',
#                      'country_name': 'Malaysia',
#                      'deaths': '92',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '57',
#                      'new_deaths': '3',
#                      'region': '',
#                      'serious_critical': '43',
#                      'tests_per_1m_population': '3,344',
#                      'total_cases_per_1m_population': '169',
#                      'total_recovered': '3,349',
#                      'total_tests': '108,216'},
#                     {'active_cases': '4,336',
#                      'cases': '5,044',
#                      'country_name': 'Dominican Republic',
#                      'deaths': '245',
#                      'deaths_per_1m_population': '23',
#                      'new_cases': '80',
#                      'new_deaths': '10',
#                      'region': '',
#                      'serious_critical': '126',
#                      'tests_per_1m_population': '1,565',
#                      'total_cases_per_1m_population': '465',
#                      'total_recovered': '463',
#                      'total_tests': '16,973'},
#                     {'active_cases': '4,318',
#                      'cases': '4,658',
#                      'country_name': 'Panama',
#                      'deaths': '136',
#                      'deaths_per_1m_population': '32',
#                      'new_cases': '191',
#                      'new_deaths': '10',
#                      'region': '',
#                      'serious_critical': '98',
#                      'tests_per_1m_population': '4,866',
#                      'total_cases_per_1m_population': '1,080',
#                      'total_recovered': '204',
#                      'total_tests': '20,996'},
#                     {'active_cases': '3,149',
#                      'cases': '4,149',
#                      'country_name': 'Colombia',
#                      'deaths': '196',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '172',
#                      'new_deaths': '7',
#                      'region': '',
#                      'serious_critical': '98',
#                      'tests_per_1m_population': '1,281',
#                      'total_cases_per_1m_population': '82',
#                      'total_recovered': '804',
#                      'total_tests': '65,169'},
#                     {'active_cases': '1,873',
#                      'cases': '4,014',
#                      'country_name': 'Finland',
#                      'deaths': '141',
#                      'deaths_per_1m_population': '25',
#                      'new_cases': '146',
#                      'new_deaths': '43',
#                      'region': '',
#                      'serious_critical': '63',
#                      'tests_per_1m_population': '11,154',
#                      'total_cases_per_1m_population': '724',
#                      'total_recovered': '2,000',
#                      'total_tests': '61,800'},
#                     {'active_cases': '2,870',
#                      'cases': '3,618',
#                      'country_name': 'Luxembourg',
#                      'deaths': '78',
#                      'deaths_per_1m_population': '125',
#                      'new_cases': '60',
#                      'new_deaths': '3',
#                      'region': '',
#                      'serious_critical': '32',
#                      'tests_per_1m_population': '55,852',
#                      'total_cases_per_1m_population': '5,780',
#                      'total_recovered': '670',
#                      'total_tests': '34,962'},
#                     {'active_cases': '2,356',
#                      'cases': '3,490',
#                      'country_name': 'Egypt',
#                      'deaths': '264',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '157',
#                      'new_deaths': '14',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '537',
#                      'total_cases_per_1m_population': '34',
#                      'total_recovered': '870',
#                      'total_tests': '55,000'},
#                     {'active_cases': '2,352',
#                      'cases': '3,465',
#                      'country_name': 'South Africa',
#                      'deaths': '58',
#                      'deaths_per_1m_population': '1.0',
#                      'new_cases': '165',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '36',
#                      'tests_per_1m_population': '2,140',
#                      'total_cases_per_1m_population': '58',
#                      'total_recovered': '1,055',
#                      'total_tests': '126,937'},
#                     {'active_cases': '3,185',
#                      'cases': '3,382',
#                      'country_name': 'Bangladesh',
#                      'deaths': '110',
#                      'deaths_per_1m_population': '0.7',
#                      'new_cases': '434',
#                      'new_deaths': '9',
#                      'region': '',
#                      'serious_critical': '1',
#                      'tests_per_1m_population': '180',
#                      'total_cases_per_1m_population': '21',
#                      'total_recovered': '87',
#                      'total_tests': '29,578'},
#                     {'active_cases': '2,671',
#                      'cases': '3,209',
#                      'country_name': 'Morocco',
#                      'deaths': '145',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '163',
#                      'new_deaths': '2',
#                      'region': '',
#                      'serious_critical': '1',
#                      'tests_per_1m_population': '490',
#                      'total_cases_per_1m_population': '87',
#                      'total_recovered': '393',
#                      'total_tests': '18,100'},
#                     {'active_cases': '2,044',
#                      'cases': '3,031',
#                      'country_name': 'Argentina',
#                      'deaths': '147',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '0',
#                      'new_deaths': '5',
#                      'region': '',
#                      'serious_critical': '123',
#                      'tests_per_1m_population': '810',
#                      'total_cases_per_1m_population': '67',
#                      'total_recovered': '840',
#                      'total_tests': '36,611'},
#                     {'active_cases': '1,267',
#                      'cases': '2,811',
#                      'country_name': 'Algeria',
#                      'deaths': '392',
#                      'deaths_per_1m_population': '9',
#                      'new_cases': '93',
#                      'new_deaths': '8',
#                      'region': '',
#                      'serious_critical': '40',
#                      'tests_per_1m_population': '148',
#                      'total_cases_per_1m_population': '64',
#                      'total_recovered': '1,152',
#                      'total_tests': '6,500'},
#                     {'active_cases': '655',
#                      'cases': '2,811',
#                      'country_name': 'Thailand',
#                      'deaths': '48',
#                      'deaths_per_1m_population': '0.7',
#                      'new_cases': '19',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '61',
#                      'tests_per_1m_population': '2,043',
#                      'total_cases_per_1m_population': '40',
#                      'total_recovered': '2,108',
#                      'total_tests': '142,589'},
#                     {'active_cases': '2,037',
#                      'cases': '2,614',
#                      'country_name': 'Moldova',
#                      'deaths': '72',
#                      'deaths_per_1m_population': '18',
#                      'new_cases': '66',
#                      'new_deaths': '2',
#                      'region': '',
#                      'serious_critical': '212',
#                      'tests_per_1m_population': '2,916',
#                      'total_cases_per_1m_population': '648',
#                      'total_recovered': '505',
#                      'total_tests': '11,763'},
#                     {'active_cases': '1,703',
#                      'cases': '2,401',
#                      'country_name': 'Greece',
#                      'deaths': '121',
#                      'deaths_per_1m_population': '12',
#                      'new_cases': '156',
#                      'new_deaths': '5',
#                      'region': '',
#                      'serious_critical': '59',
#                      'tests_per_1m_population': '5,341',
#                      'total_cases_per_1m_population': '230',
#                      'total_recovered': '577',
#                      'total_tests': '55,666'},
#                     {'active_cases': '1,598',
#                      'cases': '2,098',
#                      'country_name': 'Hungary',
#                      'deaths': '213',
#                      'deaths_per_1m_population': '22',
#                      'new_cases': '114',
#                      'new_deaths': '14',
#                      'region': '',
#                      'serious_critical': '82',
#                      'tests_per_1m_population': '5,181',
#                      'total_cases_per_1m_population': '217',
#                      'total_recovered': '287',
#                      'total_tests': '50,052'},
#                     {'active_cases': '1,657',
#                      'cases': '2,080',
#                      'country_name': 'Kuwait',
#                      'deaths': '11',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '85',
#                      'new_deaths': '2',
#                      'region': '',
#                      'serious_critical': '46',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '487',
#                      'total_recovered': '412',
#                      'total_tests': '0'},
#                     {'active_cases': '1,487',
#                      'cases': '1,995',
#                      'country_name': 'Kazakhstan',
#                      'deaths': '19',
#                      'deaths_per_1m_population': '1',
#                      'new_cases': '143',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '22',
#                      'tests_per_1m_population': '6,749',
#                      'total_cases_per_1m_population': '106',
#                      'total_recovered': '489',
#                      'total_tests': '126,727'},
#                     {'active_cases': '1,182',
#                      'cases': '1,973',
#                      'country_name': 'Bahrain',
#                      'deaths': '7',
#                      'deaths_per_1m_population': '4',
#                      'new_cases': '66',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '2',
#                      'tests_per_1m_population': '55,466',
#                      'total_cases_per_1m_population': '1,160',
#                      'total_recovered': '784',
#                      'total_tests': '94,380'},
#                     {'active_cases': '1,059',
#                      'cases': '1,908',
#                      'country_name': 'Croatia',
#                      'deaths': '48',
#                      'deaths_per_1m_population': '12',
#                      'new_cases': '27',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '18',
#                      'tests_per_1m_population': '6,482',
#                      'total_cases_per_1m_population': '465',
#                      'total_recovered': '801',
#                      'total_tests': '26,610'},
#                     {'active_cases': '351',
#                      'cases': '1,778',
#                      'country_name': 'Iceland',
#                      'deaths': '10',
#                      'deaths_per_1m_population': '29',
#                      'new_cases': '5',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '5',
#                      'tests_per_1m_population': '128,445',
#                      'total_cases_per_1m_population': '5,210',
#                      'total_recovered': '1,417',
#                      'total_tests': '43,831'},
#                     {'active_cases': '1,315',
#                      'cases': '1,678',
#                      'country_name': 'Uzbekistan',
#                      'deaths': '6',
#                      'deaths_per_1m_population': '0.2',
#                      'new_cases': '51',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '8',
#                      'tests_per_1m_population': '4,482',
#                      'total_cases_per_1m_population': '50',
#                      'total_recovered': '357',
#                      'total_tests': '150,000'},
#                     {'active_cases': '423',
#                      'cases': '1,602',
#                      'country_name': 'Iraq',
#                      'deaths': '83',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '28',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '0',
#                      'tests_per_1m_population': '1,513',
#                      'total_cases_per_1m_population': '40',
#                      'total_recovered': '1,096',
#                      'total_tests': '60,837'},
#                     {'active_cases': '1,340',
#                      'cases': '1,552',
#                      'country_name': 'Estonia',
#                      'deaths': '43',
#                      'deaths_per_1m_population': '32',
#                      'new_cases': '17',
#                      'new_deaths': '3',
#                      'region': '',
#                      'serious_critical': '9',
#                      'tests_per_1m_population': '31,822',
#                      'total_cases_per_1m_population': '1,170',
#                      'total_recovered': '169',
#                      'total_tests': '42,213'},
#                     {'active_cases': '1,262',
#                      'cases': '1,508',
#                      'country_name': 'Oman',
#                      'deaths': '8',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '98',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '3',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '295',
#                      'total_recovered': '238',
#                      'total_tests': '0'},
#                     {'active_cases': '595',
#                      'cases': '1,480',
#                      'country_name': 'Azerbaijan',
#                      'deaths': '20',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '44',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '16',
#                      'tests_per_1m_population': '10,135',
#                      'total_cases_per_1m_population': '146',
#                      'total_recovered': '865',
#                      'total_tests': '102,764'},
#                     {'active_cases': '426',
#                      'cases': '1,445',
#                      'country_name': 'New Zealand',
#                      'deaths': '13',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '5',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '3',
#                      'tests_per_1m_population': '18,562',
#                      'total_cases_per_1m_population': '300',
#                      'total_recovered': '1,006',
#                      'total_tests': '89,508'},
#                     {'active_cases': '768',
#                      'cases': '1,401',
#                      'country_name': 'Armenia',
#                      'deaths': '24',
#                      'deaths_per_1m_population': '8',
#                      'new_cases': '62',
#                      'new_deaths': '2',
#                      'region': '',
#                      'serious_critical': '30',
#                      'tests_per_1m_population': '4,701',
#                      'total_cases_per_1m_population': '473',
#                      'total_recovered': '609',
#                      'total_tests': '13,929'},
#                     {'active_cases': '1,014',
#                      'cases': '1,350',
#                      'country_name': 'Lithuania',
#                      'deaths': '38',
#                      'deaths_per_1m_population': '14',
#                      'new_cases': '24',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '17',
#                      'tests_per_1m_population': '25,990',
#                      'total_cases_per_1m_population': '496',
#                      'total_recovered': '298',
#                      'total_tests': '70,753'},
#                     {'active_cases': '1,070',
#                      'cases': '1,344',
#                      'country_name': 'Slovenia',
#                      'deaths': '77',
#                      'deaths_per_1m_population': '37',
#                      'new_cases': '9',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '25',
#                      'tests_per_1m_population': '20,672',
#                      'total_cases_per_1m_population': '646',
#                      'total_recovered': '197',
#                      'total_tests': '42,976'},
#                     {'active_cases': '854',
#                      'cases': '1,342',
#                      'country_name': 'Bosnia and Herzegovina',
#                      'deaths': '51',
#                      'deaths_per_1m_population': '16',
#                      'new_cases': '33',
#                      'new_deaths': '2',
#                      'region': '',
#                      'serious_critical': '4',
#                      'tests_per_1m_population': '5,851',
#                      'total_cases_per_1m_population': '409',
#                      'total_recovered': '437',
#                      'total_tests': '19,195'},
#                     {'active_cases': '952',
#                      'cases': '1,231',
#                      'country_name': 'North Macedonia',
#                      'deaths': '55',
#                      'deaths_per_1m_population': '26',
#                      'new_cases': '6',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '9',
#                      'tests_per_1m_population': '5,923',
#                      'total_cases_per_1m_population': '591',
#                      'total_recovered': '224',
#                      'total_tests': '12,340'},
#                     {'active_cases': '927',
#                      'cases': '1,199',
#                      'country_name': 'Slovakia',
#                      'deaths': '14',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '26',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '7',
#                      'tests_per_1m_population': '9,053',
#                      'total_cases_per_1m_population': '220',
#                      'total_recovered': '258',
#                      'total_tests': '49,428'},
#                     {'active_cases': '791',
#                      'cases': '1,163',
#                      'country_name': 'Cameroon',
#                      'deaths': '43',
#                      'deaths_per_1m_population': '2',
#                      'new_cases': '0',
#                      'new_deaths': '1',
#                      'region': '',
#                      'serious_critical': '33',
#                      'tests_per_1m_population': '0',
#                      'total_cases_per_1m_population': '44',
#                      'total_recovered': '329',
#                      'total_tests': '0'},
#                     {'active_cases': '790',
#                      'cases': '1,137',
#                      'country_name': 'Cuba',
#                      'deaths': '38',
#                      'deaths_per_1m_population': '3',
#                      'new_cases': '50',
#                      'new_deaths': '2',
#                      'region': '',
#                      'serious_critical': '18',
#                      'tests_per_1m_population': '2,685',
#                      'total_cases_per_1m_population': '100',
#                      'total_recovered': '309',
#                      'total_tests': '30,416'},
#                     {'active_cases': '906',
#                      'cases': '1,092',
#                      'country_name': 'Afghanistan',
#                      'deaths': '36',
#                      'deaths_per_1m_population': '0.9',
#                      'new_cases': '66',
#                      'new_deaths': '0',
#                      'region': '',
#                      'serious_critical': '7',
#                      'tests_per_1m_population': '165',
#                      'total_cases_per_1m_population': '28',
#                      'total_recovered': '150',
#                      'total_tests': '6,422'},
#                     {'active_cases': '934',
#                      'cases': '1,042',
#                      'country_name': 'Ghana',
#                      'deaths': '9',
#                      'deaths_per_1m_population': '0.3',
# ...
#   'serious_critical': '0',
#   'tests_per_1m_population': '615',
#   'total_cases_per_1m_population': '27',
#   'total_recovered': '8',
#   'total_tests': '714'},
#  {'active_cases': '23',
#   'cases': '28',
#   'country_name': 'Zimbabwe',
#   'deaths': '3',
#   'deaths_per_1m_population': '0.2',
#   'new_cases': '3',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '280',
#   'total_cases_per_1m_population': '2',
#   'total_recovered': '2',
#   'total_tests': '4,159'},
#  {'active_cases': '16',
#   'cases': '24',
#   'country_name': 'Angola',
#   'deaths': '2',
#   'deaths_per_1m_population': '0.06',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '0',
#   'total_cases_per_1m_population': '0.7',
#   'total_recovered': '6',
#   'total_tests': '0'},
#  {'active_cases': '22',
#   'cases': '23',
#   'country_name': 'Timor-Leste',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '1',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '244',
#   'total_cases_per_1m_population': '17',
#   'total_recovered': '1',
#   'total_tests': '322'},
#  {'active_cases': '13',
#   'cases': '23',
#   'country_name': 'Antigua and Barbuda',
#   'deaths': '3',
#   'deaths_per_1m_population': '31',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '1',
#   'tests_per_1m_population': '1,103',
#   'total_cases_per_1m_population': '235',
#   'total_recovered': '7',
#   'total_tests': '108'},
#  {'active_cases': '19',
#   'cases': '20',
#   'country_name': 'Botswana',
#   'deaths': '1',
#   'deaths_per_1m_population': '0.4',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '1,885',
#   'total_cases_per_1m_population': '9',
#   'total_recovered': '0',
#   'total_tests': '4,432'},
#  {'active_cases': '17',
#   'cases': '19',
#   'country_name': 'Laos',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '185',
#   'total_cases_per_1m_population': '3',
#   'total_recovered': '2',
#   'total_tests': '1,349'},
#  {'active_cases': '14',
#   'cases': '18',
#   'country_name': 'Belize',
#   'deaths': '2',
#   'deaths_per_1m_population': '5',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '1',
#   'tests_per_1m_population': '1,637',
#   'total_cases_per_1m_population': '45',
#   'total_recovered': '2',
#   'total_tests': '651'},
#  {'active_cases': '13',
#   'cases': '18',
#   'country_name': 'Malawi',
#   'deaths': '2',
#   'deaths_per_1m_population': '0.1',
#   'new_cases': '1',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '1',
#   'tests_per_1m_population': '22',
#   'total_cases_per_1m_population': '0.9',
#   'total_recovered': '3',
#   'total_tests': '429'},
#  {'active_cases': '15',
#   'cases': '18',
#   'country_name': 'Fiji',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '0',
#   'total_cases_per_1m_population': '20',
#   'total_recovered': '3',
#   'total_tests': '0'},
#  {'active_cases': '1',
#   'cases': '18',
#   'country_name': 'New Caledonia',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '1',
#   'tests_per_1m_population': '12,441',
#   'total_cases_per_1m_population': '63',
#   'total_recovered': '17',
#   'total_tests': '3,552'},
#  {'active_cases': '10',
#   'cases': '16',
#   'country_name': 'Namibia',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '206',
#   'total_cases_per_1m_population': '6',
#   'total_recovered': '6',
#   'total_tests': '524'},
#  {'active_cases': '8',
#   'cases': '16',
#   'country_name': 'Dominica',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '4,793',
#   'total_cases_per_1m_population': '222',
#   'total_recovered': '8',
#   'total_tests': '345'},
#  {'active_cases': '15',
#   'cases': '15',
#   'country_name': 'Saint Kitts and Nevis',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '4,643',
#   'total_cases_per_1m_population': '282',
#   'total_recovered': '0',
#   'total_tests': '247'},
#  {'active_cases': '2',
#   'cases': '15',
#   'country_name': 'Saint Lucia',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '1,982',
#   'total_cases_per_1m_population': '82',
#   'total_recovered': '13',
#   'total_tests': '364'},
#  {'active_cases': '8',
#   'cases': '14',
#   'country_name': 'Grenada',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '4',
#   'tests_per_1m_population': '818',
#   'total_cases_per_1m_population': '124',
#   'total_recovered': '6',
#   'total_tests': '92'},
#  {'active_cases': '4',
#   'cases': '14',
#   'country_name': 'CAR',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '2',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '0',
#   'total_cases_per_1m_population': '3',
#   'total_recovered': '10',
#   'total_tests': '0'},
#  {'active_cases': '2',
#   'cases': '14',
#   'country_name': 'Curaçao',
#   'deaths': '1',
#   'deaths_per_1m_population': '6',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '1,743',
#   'total_cases_per_1m_population': '85',
#   'total_recovered': '11',
#   'total_tests': '286'},
#  {'active_cases': '10',
#   'cases': '12',
#   'country_name': 'St. Vincent Grenadines',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '847',
#   'total_cases_per_1m_population': '108',
#   'total_recovered': '2',
#   'total_tests': '94'},
#  {'active_cases': '10',
#   'cases': '11',
#   'country_name': 'Turks and Caicos',
#   'deaths': '1',
#   'deaths_per_1m_population': '26',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '2,144',
#   'total_cases_per_1m_population': '284',
#   'total_recovered': '0',
#   'total_tests': '83'},
#  {'active_cases': '8',
#   'cases': '11',
#   'country_name': 'Falkland Islands',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '91,667',
#   'total_cases_per_1m_population': '3,161',
#   'total_recovered': '3',
#   'total_tests': '319'},
#  {'active_cases': '0',
#   'cases': '11',
#   'country_name': 'Greenland',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '20,257',
#   'total_cases_per_1m_population': '194',
#   'total_recovered': '11',
#   'total_tests': '1,150'},
#  {'active_cases': '9',
#   'cases': '11',
#   'country_name': 'Montserrat',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '1',
#   'tests_per_1m_population': '7,212',
#   'total_cases_per_1m_population': '2,204',
#   'total_recovered': '2',
#   'total_tests': '36'},
#  {'active_cases': '6',
#   'cases': '11',
#   'country_name': 'Seychelles',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '0',
#   'total_cases_per_1m_population': '112',
#   'total_recovered': '5',
#   'total_tests': '0'},
#  {'active_cases': '1',
#   'cases': '10',
#   'country_name': 'Nicaragua',
#   'deaths': '2',
#   'deaths_per_1m_population': '0.3',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '0',
#   'total_cases_per_1m_population': '2',
#   'total_recovered': '7',
#   'total_tests': '0'},
#  {'active_cases': '7',
#   'cases': '10',
#   'country_name': 'Gambia',
#   'deaths': '1',
#   'deaths_per_1m_population': '0.4',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '131',
#   'total_cases_per_1m_population': '4',
#   'total_recovered': '2',
#   'total_tests': '316'},
#  {'active_cases': '3',
#   'cases': '10',
#   'country_name': 'Suriname',
#   'deaths': '1',
#   'deaths_per_1m_population': '2',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '689',
#   'total_cases_per_1m_population': '17',
#   'total_recovered': '6',
#   'total_tests': '404'},
#  {'active_cases': '7',
#   'cases': '9',
#   'country_name': 'Vatican City',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '0',
#   'total_cases_per_1m_population': '11,236',
#   'total_recovered': '2',
#   'total_tests': '0'},
#  {'active_cases': '7',
#   'cases': '9',
#   'country_name': 'MS Zaandam',
#   'deaths': '2',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '0',
#   'total_cases_per_1m_population': '0',
#   'total_recovered': '0',
#   'total_tests': '0'},
#  {'active_cases': '0',
#   'cases': '7',
#   'country_name': 'Mauritania',
#   'deaths': '1',
#   'deaths_per_1m_population': '0.2',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '196',
#   'total_cases_per_1m_population': '2',
#   'total_recovered': '6',
#   'total_tests': '913'},
#  {'active_cases': '7',
#   'cases': '7',
#   'country_name': 'Papua New Guinea',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '68',
#   'total_cases_per_1m_population': '0.8',
#   'total_recovered': '0',
#   'total_tests': '604'},
#  {'active_cases': '4',
#   'cases': '6',
#   'country_name': 'Bhutan',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '1',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '11,359',
#   'total_cases_per_1m_population': '8',
#   'total_recovered': '2',
#   'total_tests': '8,765'},
#  {'active_cases': '0',
#   'cases': '6',
#   'country_name': 'St. Barth',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '0',
#   'total_cases_per_1m_population': '607',
#   'total_recovered': '6',
#   'total_tests': '0'},
#  {'active_cases': '6',
#   'cases': '6',
#   'country_name': 'Western Sahara',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '0',
#   'total_cases_per_1m_population': '10',
#   'total_recovered': '0',
#   'total_tests': '0'},
#  {'active_cases': '1',
#   'cases': '5',
#   'country_name': 'British Virgin Islands',
#   'deaths': '1',
#   'deaths_per_1m_population': '33',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '0',
#   'total_cases_per_1m_population': '165',
#   'total_recovered': '3',
#   'total_tests': '0'},
#  {'active_cases': '0',
#   'cases': '5',
#   'country_name': 'Burundi',
#   'deaths': '1',
#   'deaths_per_1m_population': '0.08',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '7',
#   'total_cases_per_1m_population': '0.4',
#   'total_recovered': '4',
#   'total_tests': '80'},
#  {'active_cases': '5',
#   'cases': '5',
#   'country_name': 'Caribbean Netherlands',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '4,195',
#   'total_cases_per_1m_population': '191',
#   'total_recovered': '0',
#   'total_tests': '110'},
#  {'active_cases': '4',
#   'cases': '4',
#   'country_name': 'Sao Tome and Principe',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '87',
#   'total_cases_per_1m_population': '18',
#   'total_recovered': '0',
#   'total_tests': '19'},
#  {'active_cases': '4',
#   'cases': '4',
#   'country_name': 'South Sudan',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '0',
#   'total_cases_per_1m_population': '0.4',
#   'total_recovered': '0',
#   'total_tests': '0'},
#  {'active_cases': '2',
#   'cases': '3',
#   'country_name': 'Anguilla',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '0',
#   'total_cases_per_1m_population': '200',
#   'total_recovered': '1',
#   'total_tests': '0'},
#  {'active_cases': '1',
#   'cases': '1',
#   'country_name': 'Saint Pierre Miquelon',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '0',
#   'total_cases_per_1m_population': '173',
#   'total_recovered': '0',
#   'total_tests': '0'},
#  {'active_cases': '1',
#   'cases': '1',
#   'country_name': 'Yemen',
#   'deaths': '0',
#   'deaths_per_1m_population': '0',
#   'new_cases': '0',
#   'new_deaths': '0',
#   'region': '',
#   'serious_critical': '0',
#   'tests_per_1m_population': '0',
#   'total_cases_per_1m_population': '0.03',
#   'total_recovered': '0',
#   'total_tests': '0'}]
# USA
# Spain
# Italy
# France
# Germany
# UK
# Turkey
# Iran
# China
# Russia
# Brazil
# Belgium
# Canada
# Netherlands
# Switzerland
# Portugal
# India
# Peru
# Ireland
# Sweden
# Austria
# Israel
# Saudi Arabia
# Japan
# Chile
# S. Korea
# Ecuador
# Poland
# Pakistan
# Romania
# Singapore
# Mexico
# UAE
# Denmark
# Norway
# Indonesia
# Czechia
# Serbia
# Belarus
# Australia
# Philippines
# Qatar
# Ukraine
# Malaysia
# Dominican Republic
# Panama
# Colombia
# Finland
# Luxembourg
# Egypt
# South Africa
# Bangladesh
# Morocco
# Argentina
# Algeria
# Thailand
# Moldova
# Greece
# Hungary
# Kuwait
# Kazakhstan
# Bahrain
# Croatia
# Iceland
# Uzbekistan
# Iraq
# Estonia
# Oman
# Azerbaijan
# New Zealand
# Armenia
# Lithuania
# Slovenia
# Bosnia and Herzegovina
# North Macedonia
# Slovakia
# Cameroon
# Cuba
# Afghanistan
# Ghana
# Hong Kong
# Bulgaria
# Djibouti
# Ivory Coast
# Tunisia
# Cyprus
# Latvia
#
# Andorra
# Diamond Princess
# Guinea
# Lebanon
# Costa Rica
# Nigeria
# Niger
# Albania
# Burkina Faso
# Bolivia
# Kyrgyzstan
# Uruguay
# Channel Islands
# Honduras
# San Marino
# Palestine
# Malta
# Jordan
# Taiwan
# Senegal
# Réunion
# Georgia
# DRC
# Mauritius
# Montenegro
# Mayotte
# Sri Lanka
# Isle of Man
# Kenya
# Guatemala
# Somalia
# Venezuela
# Vietnam
# Mali
# Tanzania
# El Salvador
# Jamaica
# Paraguay
# Faeroe Islands
# Congo
# Martinique
# Gabon
# Rwanda
# Guadeloupe
# Brunei
# Gibraltar
# Cambodia
# Madagascar
# Myanmar
# Trinidad and Tobago
# Ethiopia
# Sudan
# Liberia
# French Guiana
# Aruba
# Monaco
# Togo
# Bermuda
# Equatorial Guinea
# Maldives
# Liechtenstein
# Barbados
# Zambia
# Cabo Verde
# Sint Maarten
# Guyana
# Cayman Islands
# Bahamas
# Uganda
# Haiti
# French Polynesia
# Benin
# Libya
# Guinea-Bissau
# Sierra Leone
# Macao
# Nepal
# Syria
# Eritrea
# Mozambique
# Saint Martin
# Mongolia
# Chad
# Eswatini
# Zimbabwe
# Angola
# Timor-Leste
# Antigua and Barbuda
# Botswana
# Laos
# Belize
# Malawi
# Fiji
# New Caledonia
# Namibia
# Dominica
# Saint Kitts and Nevis
# Saint Lucia
# Grenada
# CAR
# Curaçao
# St. Vincent Grenadines
# Turks and Caicos
# Falkland Islands
# Greenland
# Montserrat
# Seychelles
# Nicaragua
# Gambia
# Suriname
# Vatican City
# MS Zaandam
# Mauritania
# Papua New Guinea
# Bhutan
# St. Barth
# Western Sahara
# British Virgin Islands
# Burundi
# Caribbean Netherlands
# Sao Tome and Principe
# South Sudan
# Anguilla
# Saint Pierre Miquelon
# Yemen

# %%
 results = response.json()
 print(results["countries_stat"])
# Out:
# [{'country_name': 'USA', 'cases': '816,385', 'deaths': '45,174', 'region': '', 'total_recovered': '82,693', 'new_deaths': '2,660', 'new_cases': '23,626', 'serious_critical': '14,016', 'active_cases': '688,518', 'total_cases_per_1m_population': '2,466', 'deaths_per_1m_population': '136', 'total_tests': '4,182,037', 'tests_per_1m_population': '12,634'}, {'country_name': 'Spain', 'cases': '204,178', 'deaths': '21,282', 'region': '', 'total_recovered': '82,514', 'new_deaths': '430', 'new_cases': '3,968', 'serious_critical': '7,705', 'active_cases': '100,382', 'total_cases_per_1m_population': '4,367', 'deaths_per_1m_population': '455', 'total_tests': '930,230', 'tests_per_1m_population': '19,896'}, {'country_name': 'Italy', 'cases': '183,957', 'deaths': '24,648', 'region': '', 'total_recovered': '51,600', 'new_deaths': '534', 'new_cases': '2,729', 'serious_critical': '2,471', 'active_cases': '107,709', 'total_cases_per_1m_population': '3,043', 'deaths_per_1m_population': '408', 'total_tests': '1,450,150', 'tests_per_1m_population': '23,985'}, {'country_name': 'France', 'cases': '158,050', 'deaths': '20,796', 'region': '', 'total_recovered': '39,181', 'new_deaths': '531', 'new_cases': '2,667', 'serious_critical': '5,433', 'active_cases': '98,073', 'total_cases_per_1m_population': '2,421', 'deaths_per_1m_population': '319', 'total_tests': '463,662', 'tests_per_1m_population': '7,103'}, {'country_name': 'Germany', 'cases': '148,291', 'deaths': '5,033', 'region': '', 'total_recovered': '95,200', 'new_deaths': '171', 'new_cases': '1,226', 'serious_critical': '2,889', 'active_cases': '48,058', 'total_cases_per_1m_population': '1,770', 'deaths_per_1m_population': '60', 'total_tests': '1,728,357', 'tests_per_1m_population': '20,629'}, {'country_name': 'UK', 'cases': '129,044', 'deaths': '17,337', 'region': '', 'total_recovered': 'N/A', 'new_deaths': '828', 'new_cases': '4,301', 'serious_critical': '1,559', 'active_cases': '111,363', 'total_cases_per_1m_population': '1,901', 'deaths_per_1m_population': '255', 'total_tests': '535,342', 'tests_per_1m_population': '7,886'}, {'country_name': 'Turkey', 'cases': '95,591', 'deaths': '2,259', 'region': '', 'total_recovered': '14,918', 'new_deaths': '119', 'new_cases': '4,611', 'serious_critical': '1,865', 'active_cases': '78,414', 'total_cases_per_1m_population': '1,133', 'deaths_per_1m_population': '27', 'total_tests': '713,409', 'tests_per_1m_population': '8,459'}, {'country_name': 'Iran', 'cases': '84,802', 'deaths': '5,297', 'region': '', 'total_recovered': '60,965', 'new_deaths': '88', 'new_cases': '1,297', 'serious_critical': '3,357', 'active_cases': '18,540', 'total_cases_per_1m_population': '1,010', 'deaths_per_1m_population': '63', 'total_tests': '365,723', 'tests_per_1m_population': '4,354'}, {'country_name': 'China', 'cases': '82,758', 'deaths': '4,632', 'region': '', 'total_recovered': '77,123', 'new_deaths': '0', 'new_cases': '11', 'serious_critical': '82', 'active_cases': '1,003', 'total_cases_per_1m_population': '57', 'deaths_per_1m_population': '3', 'total_tests': '0', 'tests_per_1m_population': '0'}, {'country_name': 'Russia', 'cases': '52,763', 'deaths': '456', 'region': '', 'total_recovered': '3,873', 'new_deaths': '51', 'new_cases': '5,642', 'serious_critical': '700', 'active_cases': '48,434', 'total_cases_per_1m_population': '362', 'deaths_per_1m_population': '3', 'total_tests': '2,142,604', 'tests_per_1m_population': '14,682'}, {'country_name': 'Brazil', 'cases': '43,079', 'deaths': '2,741', 'region': '', 'total_recovered': '22,991', 'new_deaths': '154', 'new_cases': '2,336', 'serious_critical': '8,318', 'active_cases': '17,347', 'total_cases_per_1m_population': '203', 'deaths_per_1m_population': '13', 'total_tests': '291,922', 'tests_per_1m_population': '1,373'}, {'country_name': 'Belgium', 'cases': '40,956', 'deaths': '5,998', 'region': '', 'total_recovered': '9,002', 'new_deaths': '170', 'new_cases': '973', 'serious_critical': '1,079', 'active_cases': '25,956', 'total_cases ...

# %%
# create a DataFrame from scratch (temporary to test
pd.DataFrame(columns=["country_name"])

# create variable to hold the value belonging to each key in the dataset
countries = []
cases = []
deaths = []
active_cases = []
new_cases = []
new_deaths = []
# total_tests = []

# for loop to store the data for each key
for key in results["countries_stat"]:
    countries.append(key['country_name'])
    cases.append(key['cases'])
    new_cases.append(key["new_cases"])
    deaths.append(key["deaths"])
    new_deaths.append(key["new_deaths"])
    active_cases.append(key["active_cases"])
    #total_tests.append(key["total_tests"])
    
print(countries)
# Out:
# ['USA', 'Spain', 'Italy', 'France', 'Germany', 'UK', 'Turkey', 'Iran', 'China', 'Russia', 'Brazil', 'Belgium', 'Canada', 'Netherlands', 'Switzerland', 'Portugal', 'India', 'Peru', 'Ireland', 'Sweden', 'Austria', 'Israel', 'Saudi Arabia', 'Japan', 'Chile', 'S. Korea', 'Ecuador', 'Poland', 'Pakistan', 'Romania', 'Singapore', 'Mexico', 'UAE', 'Denmark', 'Norway', 'Indonesia', 'Czechia', 'Serbia', 'Belarus', 'Australia', 'Philippines', 'Qatar', 'Ukraine', 'Malaysia', 'Dominican Republic', 'Panama', 'Colombia', 'Finland', 'Luxembourg', 'Egypt', 'South Africa', 'Bangladesh', 'Morocco', 'Argentina', 'Algeria', 'Thailand', 'Moldova', 'Greece', 'Hungary', 'Kuwait', 'Kazakhstan', 'Bahrain', 'Croatia', 'Iceland', 'Uzbekistan', 'Iraq', 'Estonia', 'Oman', 'Azerbaijan', 'New Zealand', 'Armenia', 'Lithuania', 'Slovenia', 'Bosnia and Herzegovina', 'North Macedonia', 'Slovakia', 'Cameroon', 'Cuba', 'Afghanistan', 'Ghana', 'Hong Kong', 'Bulgaria', 'Djibouti', 'Ivory Coast', 'Tunisia', 'Cyprus', 'Latvia', '', 'Andorra', 'Diamond Princess', 'Guinea', 'Lebanon', 'Costa Rica', 'Nigeria', 'Niger', 'Albania', 'Burkina Faso', 'Bolivia', 'Kyrgyzstan', 'Uruguay', 'Channel Islands', 'Honduras', 'San Marino', 'Palestine', 'Malta', 'Jordan', 'Taiwan', 'Senegal', 'Réunion', 'Georgia', 'DRC', 'Mauritius', 'Montenegro', 'Mayotte', 'Sri Lanka', 'Isle of Man', 'Kenya', 'Guatemala', 'Somalia', 'Venezuela', 'Vietnam', 'Mali', 'Tanzania', 'El Salvador', 'Jamaica', 'Paraguay', 'Faeroe Islands', 'Congo', 'Martinique', 'Gabon', 'Rwanda', 'Guadeloupe', 'Brunei', 'Gibraltar', 'Cambodia', 'Madagascar', 'Myanmar', 'Trinidad and Tobago', 'Ethiopia', 'Sudan', 'Liberia', 'French Guiana', 'Aruba', 'Monaco', 'Togo', 'Bermuda', 'Equatorial Guinea', 'Maldives', 'Liechtenstein', 'Barbados', 'Zambia', 'Cabo Verde', 'Sint Maarten', 'Guyana', 'Cayman Islands', 'Bahamas', 'Uganda', 'Haiti', 'French Polynesia', 'Benin', 'Libya', 'Guinea-Bissau', 'Sierra Leone', 'Macao', 'Nepal', 'Syria', 'Eritrea', 'Mozambique', 'Saint Martin', 'Mongolia', 'Chad', 'Eswatini', 'Zimbabwe', 'Angola', 'Timor-Leste', 'Antigua and Barbuda', 'Botswana', 'Laos', 'Belize', 'Malawi', 'Fiji', 'New Caledonia', 'Namibia', 'Dominica', 'Saint Kitts and Nevis', 'Saint Lucia', 'Grenada', 'CAR', 'Curaçao', 'St. Vincent Grenadines', 'Turks and Caicos', 'Falkland Islands', 'Greenland', 'Montserrat', 'Seychelles', 'Nicaragua', 'Gambia', 'Suriname', 'Vatican City', 'MS Zaandam', 'Mauritania', 'Papua New Guinea', 'Bhutan', 'St. Barth', 'Western Sahara', 'British Virgin Islands', 'Burundi', 'Caribbean Netherlands', 'Sao Tome and Principe', 'South Sudan', 'Anguilla', 'Saint Pierre Miquelon', 'Yemen']

# %%
# Store dataframe into variable permanent

data = pd.DataFrame(columns=["Country", "Total Cases", "Total Deaths", "Active Cases", "New Cases", "New Deaths"])
data['Country'] = countries
data['Total Cases'] = cases
data['Total Deaths'] = deaths
data['Active Cases'] = active_cases
data['New Cases'] = new_cases
data['New Deaths'] = new_deaths
# data['Total tests'] = total_tests
data
# Out:
#                    Country Total Cases Total Deaths Active Cases New Cases  \
# 0                      USA     816,385       45,174      688,518    23,626
# 1                    Spain     204,178       21,282      100,382     3,968
# 2                    Italy     183,957       24,648      107,709     2,729
# 3                   France     158,050       20,796       98,073     2,667
# 4                  Germany     148,291        5,033       48,058     1,226
# ..                     ...         ...          ...          ...       ...
# 208  Sao Tome and Principe           4            0            4         0
# 209            South Sudan           4            0            4         0
# 210               Anguilla           3            0            2         0
# 211  Saint Pierre Miquelon           1            0            1         0
# 212                  Yemen           1            0            1         0
#
#     New Deaths
# 0        2,660
# 1          430
# 2          534
# 3          531
# 4          171
# ..         ...
# 208          0
# 209          0
# 210          0
# 211          0
# 212          0
#
# [213 rows x 6 columns]

# %%
import gmaps
gmaps.configure(api_key='AIzaSyDL-xRNHbdNVR30ca2yBZSuIqvJ5mi54Ss')

marker_locations = [
    (-34.0, -59.166672),
    (-32.23333, -64.433327),
    (40.166672, 44.133331),
    (51.216671, 5.0833302),
    (51.333328, 4.25)
]
fig = gmaps.figure()
markers = gmaps.marker_layer(marker_locations)
fig.add_layer(markers)
fig
# Out:
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# <ipython-input-24-90a4f7e905c3> in <module>
#       9     (51.333328, 4.25)
#      10 ]
# ---> 11 fig = gmaps.figure(layout=marker_locations)
#      12 gmaps.figure()
#      13 markers = gmaps.marker_layer(marker_locations)
#
# /Applications/anaconda3/envs/myenv1/lib/python3.7/site-packages/gmaps/figure.py in figure(display_toolbar, display_errors, zoom_level, tilt, center, layout, map_type, mouse_handling)
#     219         _map=_map, _toolbar=_toolbar, _errors_box=_errors_box,
#     220         layout=layout, map_type=map_type, tilt=tilt,
# --> 221         mouse_handling=mouse_handling)
#     222     return fig
#
# /Applications/anaconda3/envs/myenv1/lib/python3.7/site-packages/gmaps/figure.py in __init__(self, *args, **kwargs)
#      49         if kwargs.get('layout') is None:
#      50             kwargs['layout'] = self._default_layout()
# ---> 51         super(Figure, self).__init__(*args, **kwargs)
#      52         self._map.map_type = self.map_type
#      53         link((self._map, 'map_type'), (self, 'map_type'))
#
# /Applications/anaconda3/envs/myenv1/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# /Applications/anaconda3/envs/myenv1/lib/python3.7/site-packages/traitlets/traitlets.py in __init__(self, *args, **kwargs)
#     995             for key, value in kwargs.items():
#     996                 if self.has_trait(key):
# --> 997                     setattr(self, key, value)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
#
# /Applications/anaconda3/envs/myenv1/lib/python3.7/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# /Applications/anaconda3/envs/myenv1/lib/python3.7/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     557
#     558     def set(self, obj, value):
# --> 559         new_value = self._validate(obj, value)
#     560         try:
#     561             old_value = obj._trait_values[self.name]
#
# /Applications/anaconda3/envs/myenv1/lib/python3.7/site-packages/traitlets/traitlets.py in _validate(self, obj, value)
#     589             return value
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#     593             value = self._cross_validate(obj, value)
#
# /Applications/anaconda3/envs/myenv1/lib/python3.7/site-packages/ipywidgets/widgets/trait_types.py in validate(self, obj, value)
#     163             return super(InstanceDict, self).validate(obj, self.klass(**value))
#     164         else:
# --> 165             return super(InstanceDict, self).validate(obj, value)
#     166
#     167     def make_dynamic_default(self):
#
# /Applications/anaconda3/envs/myenv1/lib/python3.7/site-packages/traitlets/traitlets.py in validate(self, obj, value)
#    1675             return value
#    1676         else:
# -> 1677             self.error(obj, value)
#    1678
#    1679     def info(self):
#
# /Applications/anaconda3/envs/myenv1/lib/python3.7/site-packages/traitlets/traitlets.py in error(self, obj, value)
#    1522                 % (self.name, self.info(), msg)
#    1523
# -> 1524         raise TraitError(e)
#    1525
#    1526
#
# TraitError: The 'layout' trait of a Figure instance must be a FigureLayout, but a value of class 'list' (i.e. [(-34.0, -59.166672), (-32.23333, -64.433327), (40.166672, 44.133331), (51.216671, 5.0833302), (51.333328, 4.25)]) was specified.
